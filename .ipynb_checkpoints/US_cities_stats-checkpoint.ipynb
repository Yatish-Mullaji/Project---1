# %%
import pandas as pd

# Google developer API key
#from config import gkey

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %%
#import data from csv files
jobs_2013=pd.read_csv("Idea1/msa_naicssector_2013_copy.csv")
jobs_2013.head(100)
# Out:
#    Number of Firms, Number of Establishments, Employment, and Annual Payroll by Enterprise Employment Size for Metroplitan Areas , NAICS Sectors:  2013  \
# 0                                                 NaN
# 1   SOURCE: 2013 County Business Patterns.  For in...
# 2                                        FIPS    CODE
# 3                                                 NaN
# 4                                                 NaN
# 5                                               10100
# 6                                               10100
# 7                                               10100
# 8                                               10100
# 9                                               10100
# 10                                              10100
# 11                                              10100
# 12                                              10100
# 13                                              10100
# 14                                              10100
# ...

# %%
jobs_2013_clean=jobs_2013[['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 10']]
jobs_2013_clean.head()
# Out:
#         Unnamed: 1     Unnamed: 2         Unnamed: 3  \
# 0              NaN            NaN                NaN
# 1              NaN            NaN                NaN
# 2  MSA DESCRIPTION  NAICS   CODE   NAICS DESCRIPTION
# 3              NaN            NaN                NaN
# 4              NaN            NaN                NaN
#
#                    Unnamed: 4                Unnamed: 6  Unnamed: 7  \
# 0                         NaN                       NaN         NaN
# 1                         NaN                       NaN         NaN
# 2  ENTERPRISE EMPLOYMENT SIZE  NUMBER OF ESTABLISHMENTS  EMPLOYMENT
# 3                         NaN                       NaN         NaN
# 4                         NaN                       NaN         NaN
#
#                Unnamed: 10
# 0                      NaN
# 1                      NaN
# 2  ANNUAL PAYROLL ($1,000)
# 3                      NaN
# 4                      NaN

# %%
jobs13=jobs_2013_clean.rename(columns={"Unnamed: 1": "Metro Area",
                               "Unnamed: 2": "NAICS CODE",
                               "Unnamed: 3": "Industry",       
                               "Unnamed: 4": "Totals", 
                               "Unnamed: 6": "Establishments", 
                               "Unnamed: 7": "Employment",
                               "Unnamed: 10": "Annual Payroll"})
jobs13.head(30)
# Out:
#                  Metro Area     NAICS CODE  \
# 0                       NaN            NaN
# 1                       NaN            NaN
# 2           MSA DESCRIPTION  NAICS   CODE
# 3                       NaN            NaN
# 4                       NaN            NaN
# 5   Aberdeen, SD Micro Area             --
# 6   Aberdeen, SD Micro Area             --
# 7   Aberdeen, SD Micro Area             --
# 8   Aberdeen, SD Micro Area             --
# 9   Aberdeen, SD Micro Area             --
# 10  Aberdeen, SD Micro Area             --
# 11  Aberdeen, SD Micro Area             --
# 12  Aberdeen, SD Micro Area             --
# 13  Aberdeen, SD Micro Area             --
# 14  Aberdeen, SD Micro Area             11
# 15  Aberdeen, SD Micro Area             11
# 16  Aberdeen, SD Micro Area             11
# 17  Aberdeen, SD Micro Area             11
# 18  Aberdeen, SD Micro Area             11
# 19  Aberdeen, SD Micro Area             21
# 20  Aberdeen, SD Micro Area             21
# ...

# %%
jobs13_drop=jobs13.drop(jobs13.index[[0,1,2,3,4]])
#jobs2013=jobs13_drop.set_index("Metro Area")
#jobs2013.head(30)
jobs13_drop.head(20)
# Out:
#                  Metro Area NAICS CODE  \
# 5   Aberdeen, SD Micro Area         --
# 6   Aberdeen, SD Micro Area         --
# 7   Aberdeen, SD Micro Area         --
# 8   Aberdeen, SD Micro Area         --
# 9   Aberdeen, SD Micro Area         --
# 10  Aberdeen, SD Micro Area         --
# 11  Aberdeen, SD Micro Area         --
# 12  Aberdeen, SD Micro Area         --
# 13  Aberdeen, SD Micro Area         --
# 14  Aberdeen, SD Micro Area         11
# 15  Aberdeen, SD Micro Area         11
# 16  Aberdeen, SD Micro Area         11
# 17  Aberdeen, SD Micro Area         11
# 18  Aberdeen, SD Micro Area         11
# 19  Aberdeen, SD Micro Area         21
# 20  Aberdeen, SD Micro Area         21
# 21  Aberdeen, SD Micro Area         21
# 22  Aberdeen, SD Micro Area         21
# 23  Aberdeen, SD Micro Area         22
# 24  Aberdeen, SD Micro Area         22
#
#                                          Industry        Totals  \
# ...

# %%
#filtering data for San Francisco
jobs2013_SF=jobs13_drop.loc[jobs13_drop['Metro Area'] == "San Francisco-Oakland-Hayward, CA Metro Area"]
jobs2013_SF.head()
# Out:
#                                           Metro Area NAICS CODE Industry  \
# 121002  San Francisco-Oakland-Hayward, CA Metro Area         --    Total
# 121003  San Francisco-Oakland-Hayward, CA Metro Area         --    Total
# 121004  San Francisco-Oakland-Hayward, CA Metro Area         --    Total
# 121005  San Francisco-Oakland-Hayward, CA Metro Area         --    Total
# 121006  San Francisco-Oakland-Hayward, CA Metro Area         --    Total
#
#             Totals Establishments Employment Annual Payroll
# 121002  01:  Total        121,802  1,893,104    144,004,635
# 121003    02:  0-4         58,983     99,192      5,133,420
# 121004    03:  5-9         17,111    111,369      5,056,023
# 121005  04:  10-19         11,014    139,653      6,737,579
# 121006    05:  <20         87,108    350,214     16,927,022

# %%
#filtering data for Houston
jobs2013_HU=jobs13_drop.loc[jobs13_drop['Metro Area'] == "Houston-The Woodlands-Sugar Land, TX Metro Area"]
jobs2013_HU.head()
# Out:
#                                             Metro Area NAICS CODE Industry  \
# 61524  Houston-The Woodlands-Sugar Land, TX Metro Area         --    Total
# 61525  Houston-The Woodlands-Sugar Land, TX Metro Area         --    Total
# 61526  Houston-The Woodlands-Sugar Land, TX Metro Area         --    Total
# 61527  Houston-The Woodlands-Sugar Land, TX Metro Area         --    Total
# 61528  Houston-The Woodlands-Sugar Land, TX Metro Area         --    Total
#
#            Totals Establishments Employment Annual Payroll
# 61524  01:  Total        129,490  2,449,510    146,411,921
# 61525    02:  0-4         58,231     98,902      5,152,243
# 61526    03:  5-9         17,141    111,400      4,679,537
# 61527  04:  10-19         10,933    140,476      6,175,973
# 61528    05:  <20         86,305    350,778     16,007,753

# %%
#filtering data for Austin
jobs2013_AU=jobs13_drop.loc[jobs13_drop['Metro Area'] == "Austin, MN Micro Area"]
jobs2013_AU.head()
# Out:
#                  Metro Area NAICS CODE Industry      Totals Establishments  \
# 8501  Austin, MN Micro Area         --    Total  01:  Total            861
# 8502  Austin, MN Micro Area         --    Total    02:  0-4            385
# 8503  Austin, MN Micro Area         --    Total    03:  5-9            116
# 8504  Austin, MN Micro Area         --    Total  04:  10-19             91
# 8505  Austin, MN Micro Area         --    Total    05:  <20            592
#
#      Employment Annual Payroll
# 8501     14,009        545,973
# 8502        695         17,120
# 8503        750         20,286
# 8504      1,112         31,369
# 8505      2,557         68,775

# %%
#filtering data for Detroit
jobs2013_DE=jobs13_drop.loc[jobs13_drop['Metro Area'] == "Detroit-Warren-Dearborn, MI Metro Area"]
jobs2013_DE.head()
# Out:
#                                    Metro Area NAICS CODE Industry      Totals  \
# 36779  Detroit-Warren-Dearborn, MI Metro Area         --    Total  01:  Total
# 36780  Detroit-Warren-Dearborn, MI Metro Area         --    Total    02:  0-4
# 36781  Detroit-Warren-Dearborn, MI Metro Area         --    Total    03:  5-9
# 36782  Detroit-Warren-Dearborn, MI Metro Area         --    Total  04:  10-19
# 36783  Detroit-Warren-Dearborn, MI Metro Area         --    Total    05:  <20
#
#       Establishments Employment Annual Payroll
# 36779         97,343  1,621,981     80,845,758
# 36780         46,158     75,972      3,228,938
# 36781         13,500     88,160      3,223,000
# 36782          8,563    110,229      4,307,059
# 36783         68,221    274,361     10,758,997

# %%
#filtering data for Chicago
jobs2013_SF=jobs13_drop.loc[jobs13_drop['Metro Area'] == "Chicago-Naperville-Elgin, IL-IN-WI Metro Area"]
jobs2013_SF.head()
# Out:
#                                           Metro Area NAICS CODE Industry  \
# 25857  Chicago-Naperville-Elgin, IL-IN-WI Metro Area         --    Total
# 25858  Chicago-Naperville-Elgin, IL-IN-WI Metro Area         --    Total
# 25859  Chicago-Naperville-Elgin, IL-IN-WI Metro Area         --    Total
# 25860  Chicago-Naperville-Elgin, IL-IN-WI Metro Area         --    Total
# 25861  Chicago-Naperville-Elgin, IL-IN-WI Metro Area         --    Total
#
#            Totals Establishments Employment Annual Payroll
# 25857  01:  Total        239,691  4,004,396    215,198,548
# 25858    02:  0-4        123,694    188,121      8,799,486
# 25859    03:  5-9         29,230    189,982      7,782,966
# 25860  04:  10-19         18,908    243,631     10,553,045
# 25861    05:  <20        171,832    621,734     27,135,497

# %%
#filtering data for Boston
jobs2013_BO=jobs13_drop.loc[jobs13_drop['Metro Area'] == "Boston-Cambridge-Newton, MA-NH Metro Area"]
jobs2013_BO.head()
# Out:
#                                       Metro Area NAICS CODE Industry  \
# 16666  Boston-Cambridge-Newton, MA-NH Metro Area         --    Total
# 16667  Boston-Cambridge-Newton, MA-NH Metro Area         --    Total
# 16668  Boston-Cambridge-Newton, MA-NH Metro Area         --    Total
# 16669  Boston-Cambridge-Newton, MA-NH Metro Area         --    Total
# 16670  Boston-Cambridge-Newton, MA-NH Metro Area         --    Total
#
#            Totals Establishments Employment Annual Payroll
# 16666  01:  Total        124,705  2,357,646    148,004,728
# 16667    02:  0-4         57,861     98,629      5,044,957
# 16668    03:  5-9         17,465    113,584      5,063,421
# 16669  04:  10-19         11,062    142,680      6,784,398
# 16670    05:  <20         86,388    354,893     16,892,776

# %%
#filtering data for New York
jobs2013_NY=jobs13_drop.loc[jobs13_drop['Metro Area'] == "New York-Newark-Jersey City, NY-NJ-PA Metro Area"]
jobs2013_NY.head()
# Out:
#                                              Metro Area NAICS CODE Industry  \
# 97105  New York-Newark-Jersey City, NY-NJ-PA Metro Area         --    Total
# 97106  New York-Newark-Jersey City, NY-NJ-PA Metro Area         --    Total
# 97107  New York-Newark-Jersey City, NY-NJ-PA Metro Area         --    Total
# 97108  New York-Newark-Jersey City, NY-NJ-PA Metro Area         --    Total
# 97109  New York-Newark-Jersey City, NY-NJ-PA Metro Area         --    Total
#
#            Totals Establishments Employment Annual Payroll
# 97105  01:  Total        564,394  7,870,219    517,668,564
# 97106    02:  0-4        328,343    539,002     24,634,689
# 97107    03:  5-9         74,507    483,644     20,774,758
# 97108  04:  10-19         43,627    564,850     26,381,219
# 97109    05:  <20        446,477  1,587,496     71,790,666

# %%
jobs2013['Industry'].unique()
# Out:
# array(['Total', 'Agriculture, Forestry, Fishing and Hunting',
#        'Mining, Quarrying, and Oil and Gas Extraction', 'Utilities',
#        'Construction', 'Manufacturing', 'Wholesale Trade', 'Retail Trade',
#        'Transportation and Warehousing', 'Information',
#        'Finance and Insurance', 'Real Estate and Rental and Leasing',
#        'Professional, Scientific, and Technical Services',
#        'Management of Companies and Enterprises',
#        'Administrative and Support and Waste Management and Remediation Services',
#        'Educational Services', 'Health Care and Social Assistance',
#        'Arts, Entertainment, and Recreation',
#        'Accommodation and Food Services',
#        'Other Services (except Public Administration)',
#        'Industries not classified'], dtype=object)
