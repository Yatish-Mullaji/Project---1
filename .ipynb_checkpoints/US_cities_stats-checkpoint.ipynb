# %%
import pandas as pd

# Google developer API key
#from config import gkey

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %% [markdown]
# # Data for 2006

# %%
#import data from csv files
file_jobs_2006=pd.read_csv("Idea1/business_2006.csv")
file_jobs_2006.head(1)
# Out:
#    FIPS   MSA CODE                              MSA DESCRIPTION CODE  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area   --
#
#   NAICS DESCRIPTION DATA TYPE TOTAL  0-4  5-9 10-19 20-99 100-499 500+
# 0             Total     Firms   932  491  155   103    81      26   76

# %%
file_jobs_2006_clean=file_jobs_2006.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'DATA TYPE': 'Filter',#total for years after 2013
                                                   'TOTAL': 'Total',
                                                   })
file_jobs_2006_clean.head()
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
# 1            10020  Abbeville, LA Micropolitan Statistical Area    --
# 2            10020  Abbeville, LA Micropolitan Statistical Area    --
# 3            10020  Abbeville, LA Micropolitan Statistical Area    --
# 4            10020  Abbeville, LA Micropolitan Statistical Area    11
#
#                                             Industry                   Filter  \
# 0                                              Total                    Firms
# 1                                              Total           Establishments
# 2                                              Total               Employment
# 3                                              Total  Annual Payroll ($1,000)
# 4  Forestry, Fishing, Hunting, and Agriculture Su...                    Firms
#
#      Total     0-4     5-9   10-19   20-99 100-499    500+
# 0      932     491     155     103      81      26      76
# 1      994     491     156     106      94      40     107
# 2    9,829     806     999   1,342   2,490   1,709   2,483
# 3  286,576  22,928  20,984  31,933  71,014  65,542  74,175
# 4        9       7       2       0       0       0       0

# %%
jobs_2006=file_jobs_2006_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Total']]
jobs_2006.head()
# Out:
#                                     Metro Area NAICS  \
# 0  Abbeville, LA Micropolitan Statistical Area    --
# 1  Abbeville, LA Micropolitan Statistical Area    --
# 2  Abbeville, LA Micropolitan Statistical Area    --
# 3  Abbeville, LA Micropolitan Statistical Area    --
# 4  Abbeville, LA Micropolitan Statistical Area    11
#
#                                             Industry                   Filter  \
# 0                                              Total                    Firms
# 1                                              Total           Establishments
# 2                                              Total               Employment
# 3                                              Total  Annual Payroll ($1,000)
# 4  Forestry, Fishing, Hunting, and Agriculture Su...                    Firms
#
#      Total
# 0      932
# 1      994
# 2    9,829
# 3  286,576
# 4        9

# %%
jobs_2006['Industry'].unique()
# Out:
# array(['Total', 'Forestry, Fishing, Hunting, and Agriculture Support',
#        'Mining', 'Utilities', 'Construction', 'Manufacturing',
#        'Wholesale Trade', 'Retail Trade',
#        'Transportation and Warehousing', 'Information',
#        'Finance and Insurance', 'Real Estate and Rental and Leasing',
#        'Professional, Scientific, and Technical Services',
#        'Management of Companies and Enterprises',
#        'Administrative and Support and Waste Management and Remediation Services',
#        'Educational Services', 'Health Care and Social Assistance',
#        'Arts, Entertainment, and Recreation',
#        'Accommodation and Food Services',
#        'Other Services (except Public Administration)', 'Unclassified'],
#       dtype=object)

# %%
cities_2006=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       #'Houston-Baytown-Sugar Land, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Newark-Edison, NY-NJ-PA Metropolitan Statistical Area']

industries_2006=['Mining', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2006=['Establishments', 'Employment', 'Annual Payroll ($1,000)']

# %%
jobs_2006_cities=jobs_2006[jobs_2006['Metro Area'].isin(cities_2006)]
jobs_2006_ind=jobs_2006_cities[jobs_2006_cities['Industry'].isin(industries_2006)]
jobs_2006_filtered=jobs_2006_ind[jobs_2006_ind['Filter'].isin(filters_2006)]
jobs_2006_filtered.to_csv('jobs_2006.csv')
jobs_2006_filtered.head()
# Out:
#                                              Metro Area  NAICS       Industry  \
# 4661  Austin-Round Rock, TX Metropolitan Statistical...     21         Mining
# 4662  Austin-Round Rock, TX Metropolitan Statistical...     21         Mining
# 4663  Austin-Round Rock, TX Metropolitan Statistical...     21         Mining
# 4673  Austin-Round Rock, TX Metropolitan Statistical...  31-33  Manufacturing
# 4674  Austin-Round Rock, TX Metropolitan Statistical...  31-33  Manufacturing
#
#                        Filter   Total
# 4661           Establishments     168
# 4662               Employment   1,439
# 4663  Annual Payroll ($1,000)  70,819
# 4673           Establishments   1,202
# 4674               Employment  50,637

# %% [markdown]
# # Data for 2007

# %%
#import data from csv files
file_jobs_2007=pd.read_csv("Idea1/business_2007.csv")
file_jobs_2007.head(2)
# Out:
#    FIPS   MSA CODE                              MSA DESCRIPTION CODE  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area   --
# 1            10020  Abbeville, LA Micropolitan Statistical Area   --
#
#   NAICS DESCRIPTION         SIZE NUMBERS OF FIRMS NUMBERS OF ESTABLISHMENTS  \
# 0             Total  01:   Total              969                     1,037
# 1             Total    02:   0-4              516                       516
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     10,100                   NaN                     G
# 1        934                   NaN                     G
#
#   ANNUAL PAYROLL (1000) ANNUAL PAYROLL NOISE FLAG ESTIMATED RECEIPTS (1000)  \
# 0               308,439                         G                 2,827,746
# 1                26,472                         G                   196,261
#
#   ESTIMATED RECEIPT NOISE FLAG
# 0                            H
# 1                            G

# %%
file_jobs_2007_clean=file_jobs_2007.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                    ' SIZE': 'Filter',
                                                   'NUMBERS OF ESTABLISHMENTS': 'Establishments',
                                                   'EMPLOYMENT': 'Employment',
                                                   'ANNUAL PAYROLL (1000)': "Annual Payroll"})
file_jobs_2007_clean.head(2)
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
# 1            10020  Abbeville, LA Micropolitan Statistical Area    --
#
#   Industry       Filter NUMBERS OF FIRMS Establishments Employment  \
# 0    Total  01:   Total              969          1,037     10,100
# 1    Total    02:   0-4              516            516        934
#
#   EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG Annual Payroll  \
# 0                   NaN                     G        308,439
# 1                   NaN                     G         26,472
#
#   ANNUAL PAYROLL NOISE FLAG ESTIMATED RECEIPTS (1000)  \
# 0                         G                 2,827,746
# 1                         G                   196,261
#
#   ESTIMATED RECEIPT NOISE FLAG
# 0                            H
# 1                            G

# %%
jobs_2007=file_jobs_2007_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Employment', 'Annual Payroll', 'Establishments']]
jobs_2007.head()
# Out:
#                                     Metro Area NAICS Industry       Filter  \
# 0  Abbeville, LA Micropolitan Statistical Area    --    Total  01:   Total
# 1  Abbeville, LA Micropolitan Statistical Area    --    Total    02:   0-4
# 2  Abbeville, LA Micropolitan Statistical Area    --    Total    03:   5-9
# 3  Abbeville, LA Micropolitan Statistical Area    --    Total  04:   10-19
# 4  Abbeville, LA Micropolitan Statistical Area    --    Total    05:   <20
#
#   Employment Annual Payroll Establishments
# 0     10,100        308,439          1,037
# 1        934         26,472            516
# 2      1,019         22,801            161
# 3      1,211         33,120             97
# 4      3,164         82,393            774

# %%
cities_2007=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       'Houston-Sugar Land-Baytown, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Northern New Jersey-Long Island, NY-NJ-PA Metropolitan Statistical']

industries_2007=['Mining', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2007=['01:   Total']

# %%
jobs_2007_cities=jobs_2007[jobs_2007['Metro Area'].isin(cities_2007)]
jobs_2007_ind=jobs_2007_cities[jobs_2007_cities['Industry'].isin(industries_2007)]
jobs_2007_filtered=jobs_2007_ind[jobs_2007_ind['Filter'].isin(filters_2007)]
jobs_2007_filtered.head(10)
# Out:
#                                               Metro Area  NAICS  \
# 9272   Austin-Round Rock, TX Metropolitan Statistical...     21
# 9299   Austin-Round Rock, TX Metropolitan Statistical...  31-33
# 9335   Austin-Round Rock, TX Metropolitan Statistical...     51
# 9344   Austin-Round Rock, TX Metropolitan Statistical...     52
# 9362   Austin-Round Rock, TX Metropolitan Statistical...     54
# 17222  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     21
# 17249  Boston-Cambridge-Quincy, MA-NH Metropolitan St...  31-33
# 17285  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     51
# 17294  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     52
# 17312  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     54
#
#                                                Industry       Filter  \
# 9272                                             Mining  01:   Total
# 9299                                      Manufacturing  01:   Total
# 9335                                        Information  01:   Total
# 9344                              Finance and Insurance  01:   Total
# 9362   Professional, Scientific, and Technical Services  01:   Total
# 17222                                            Mining  01:   Total
# 17249                                     Manufacturing  01:   Total
# 17285                                       Information  01:   Total
# 17294                             Finance and Insurance  01:   Total
# 17312  Professional, Scientific, and Technical Services  01:   Total
#
#       Employment Annual Payroll Establishments
# 9272       1,668         86,654            167
# 9299      48,312      2,608,297          1,239
# 9335      24,509      1,764,534          1,007
# 9344      31,890      2,003,265          2,805
# 9362      61,307      4,263,545          6,239
# 17222        523         26,107             42
# 17249    179,741     11,618,709          5,054
# 17285     91,919      7,655,203          2,994
# 17294    184,988     19,940,756          7,625
# 17312    229,615     20,279,071         18,095

# %% [markdown]
# # Data for 2008

# %%
#import data from csv files
file_jobs_2008=pd.read_csv("Idea1/business_2008.csv")
file_jobs_2008.head(1)
# Out:
#    FIPS   MSA CODE                              MSA DESCRIPTION CODE  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area   --
#
#   NAICS DESCRIPTION        SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0             Total  1:   Total             962                    1,031
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     10,120                   NaN                     G
#
#   ANNUAL PAYROLLL (1000) NOISE FLAG
# 0                327,131          G

# %%
file_jobs_2008_clean=file_jobs_2008.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                    ' SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishments',
                                                   'EMPLOYMENT': 'Employment',
                                                   'ANNUAL PAYROLLL (1000)': "Annual Payroll"})
file_jobs_2008_clean.head(1)
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
#
#   Industry      Filter NUMBER OF FIRMS Establishments Employment  \
# 0    Total  1:   Total             962          1,031     10,120
#
#   EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG Annual Payroll NOISE FLAG
# 0                   NaN                     G        327,131          G

# %%
jobs_2008=file_jobs_2008_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Employment', 'Annual Payroll', 'Establishments']]
jobs_2008.head(1)
# Out:
#                                     Metro Area NAICS Industry      Filter  \
# 0  Abbeville, LA Micropolitan Statistical Area    --    Total  1:   Total
#
#   Employment Annual Payroll Establishments
# 0     10,120        327,131          1,031

# %%
cities_2008=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       'Houston-Sugar Land-Baytown, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Northern New Jersey-Long Island, NY-NJ-PA Metropolitan Statistical']

industries_2008=['Mining, quarrying, and oil and gas extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and insurance', 
            'Professional, scientific, and technical services']
            
filters_2008=['1:   Total']

# %%
jobs_2008_cities=jobs_2008[jobs_2008['Metro Area'].isin(cities_2008)]
jobs_2008_ind=jobs_2008_cities[jobs_2008_cities['Industry'].isin(industries_2008)]
jobs_2008_filtered=jobs_2008_ind[jobs_2008_ind['Filter'].isin(filters_2008)]
jobs_2008_filtered.head(10)
# Out:
#                                               Metro Area  NAICS  \
# 9299   Austin-Round Rock, TX Metropolitan Statistical...     21
# 9326   Austin-Round Rock, TX Metropolitan Statistical...  31-33
# 9362   Austin-Round Rock, TX Metropolitan Statistical...     51
# 9371   Austin-Round Rock, TX Metropolitan Statistical...     52
# 9389   Austin-Round Rock, TX Metropolitan Statistical...     54
# 17245  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     21
# 17272  Boston-Cambridge-Quincy, MA-NH Metropolitan St...  31-33
# 17308  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     51
# 17317  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     52
# 17335  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     54
#
#                                                Industry      Filter  \
# 9299      Mining, quarrying, and oil and gas extraction  1:   Total
# 9326                                      Manufacturing  1:   Total
# 9362                                        Information  1:   Total
# 9371                              Finance and insurance  1:   Total
# 9389   Professional, scientific, and technical services  1:   Total
# 17245     Mining, quarrying, and oil and gas extraction  1:   Total
# 17272                                     Manufacturing  1:   Total
# 17308                                       Information  1:   Total
# 17317                             Finance and insurance  1:   Total
# 17335  Professional, scientific, and technical services  1:   Total
#
#       Employment Annual Payroll Establishments
# 9299       1,864        116,587            180
# 9326      45,819      2,624,636          1,266
# 9362      25,837      1,873,276            981
# 9371      33,540      2,213,091          2,876
# 9389      64,167      4,545,196          6,293
# 17245        579         36,692             48
# 17272    175,921     10,999,921          5,000
# 17308     91,343      7,976,741          3,056
# 17317    193,053     20,961,033          7,629
# 17335    229,414     21,049,908         17,458

# %% [markdown]
# # Data for 2009

# %%
#import data from csv files
file_jobs_2009=pd.read_csv("Idea1/business_2009.csv")
file_jobs_2009.head(1)
# Out:
#    FIPS   MSA CODE                              MSA DESCRIPTION CODE  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area   --
#
#   NAICS DESCRIPTION        SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0             Total  1:   Total             963                    1,037
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     10,490                   NaN                     G
#
#   ANNUAL PAYROLLL (1000) NOISE FLAG
# 0                334,997          G

# %%
file_jobs_2009_clean=file_jobs_2009.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                    ' SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishments',
                                                   'EMPLOYMENT': 'Employment',
                                                   'ANNUAL PAYROLLL (1000)': "Annual Payroll"})
file_jobs_2009_clean.head(1)
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
#
#   Industry      Filter NUMBER OF FIRMS Establishments Employment  \
# 0    Total  1:   Total             963          1,037     10,490
#
#   EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG Annual Payroll NOISE FLAG
# 0                   NaN                     G        334,997          G

# %%
jobs_2009=file_jobs_2009_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Employment', 'Annual Payroll', 'Establishments']]
jobs_2009.head(1)
# Out:
#                                     Metro Area NAICS Industry      Filter  \
# 0  Abbeville, LA Micropolitan Statistical Area    --    Total  1:   Total
#
#   Employment Annual Payroll Establishments
# 0     10,490        334,997          1,037

# %%
cities_2009=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       'Houston-Sugar Land-Baytown, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Northern New Jersey-Long Island, NY-NJ-PA Metropolitan Statistical']

industries_2009=['Mining, quarrying, and oil and gas extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and insurance', 
            'Professional, scientific, and technical services']
            
filters_2009=['1:   Total']

# %%
jobs_2009_cities=jobs_2009[jobs_2009['Metro Area'].isin(cities_2009)]
jobs_2009_ind=jobs_2009_cities[jobs_2009_cities['Industry'].isin(industries_2009)]
jobs_2009_filtered=jobs_2009_ind[jobs_2009_ind['Filter'].isin(filters_2009)]
jobs_2009_filtered.head(10)
#jobs_2008_ind.head()
# Out:
#                                               Metro Area  NAICS  \
# 9295   Austin-Round Rock, TX Metropolitan Statistical...     21
# 9322   Austin-Round Rock, TX Metropolitan Statistical...  31-33
# 9358   Austin-Round Rock, TX Metropolitan Statistical...     51
# 9367   Austin-Round Rock, TX Metropolitan Statistical...     52
# 9385   Austin-Round Rock, TX Metropolitan Statistical...     54
# 17265  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     21
# 17292  Boston-Cambridge-Quincy, MA-NH Metropolitan St...  31-33
# 17328  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     51
# 17337  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     52
# 17355  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     54
#
#                                                Industry      Filter  \
# 9295      Mining, quarrying, and oil and gas extraction  1:   Total
# 9322                                      Manufacturing  1:   Total
# 9358                                        Information  1:   Total
# 9367                              Finance and insurance  1:   Total
# 9385   Professional, scientific, and technical services  1:   Total
# 17265     Mining, quarrying, and oil and gas extraction  1:   Total
# 17292                                     Manufacturing  1:   Total
# 17328                                       Information  1:   Total
# 17337                             Finance and insurance  1:   Total
# 17355  Professional, scientific, and technical services  1:   Total
#
#       Employment Annual Payroll Establishments
# 9295       1,680        101,458            184
# 9322      42,278      2,366,965          1,219
# 9358      25,888      1,840,850            964
# 9367      33,658      2,106,507          2,944
# 9385      64,143      4,878,615          6,378
# 17265        491         28,041             45
# 17292    159,618      9,938,530          4,736
# 17328     87,665      7,696,518          2,858
# 17337    178,630     18,530,569          7,393
# 17355    223,575     20,193,936         17,170

# %% [markdown]
# # Data for 2010

# %%
#import data from csv files
file_jobs_2010=pd.read_csv("Idea1/business_2010.csv")
file_jobs_2010.head(1)
# Out:
#    FIPS   MSA CODE                              MSA DESCRIPTION CODE  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area   --
#
#   NAICS DESCRIPTION        SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0             Total  1:   Total             953                    1,024
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     10,053                   NaN                     G
#
#   ANNUAL PAYROLLL (1000) NOISE FLAG
# 0                347,335          G

# %%
file_jobs_2010_clean=file_jobs_2010.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                    ' SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishments',
                                                   'EMPLOYMENT': 'Employment',
                                                   'ANNUAL PAYROLLL (1000)': "Annual Payroll"})
file_jobs_2010_clean.head(1)
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
#
#   Industry      Filter NUMBER OF FIRMS Establishments Employment  \
# 0    Total  1:   Total             953          1,024     10,053
#
#   EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG Annual Payroll NOISE FLAG
# 0                   NaN                     G        347,335          G

# %%
jobs_2010=file_jobs_2010_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Employment', 'Annual Payroll', 'Establishments']]
jobs_2010.head(1)
# Out:
#                                     Metro Area NAICS Industry      Filter  \
# 0  Abbeville, LA Micropolitan Statistical Area    --    Total  1:   Total
#
#   Employment Annual Payroll Establishments
# 0     10,053        347,335          1,024

# %%
cities_2010=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       'Houston-Sugar Land-Baytown, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Northern New Jersey-Long Island, NY-NJ-PA Metropolitan Statistical']

industries_2010=['Mining, quarrying, and oil and gas extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and insurance', 
            'Professional, scientific, and technical services']
            
filters_2010=['1:   Total']

# %%
jobs_2010_cities=jobs_2010[jobs_2010['Metro Area'].isin(cities_2010)]
jobs_2010_ind=jobs_2010_cities[jobs_2010_cities['Industry'].isin(industries_2010)]
jobs_2010_filtered=jobs_2010_ind[jobs_2010_ind['Filter'].isin(filters_2010)]
jobs_2010_filtered.head(10)
#jobs_2008_ind.head()
# Out:
#                                               Metro Area  NAICS  \
# 9308   Austin-Round Rock, TX Metropolitan Statistical...     21
# 9335   Austin-Round Rock, TX Metropolitan Statistical...  31-33
# 9371   Austin-Round Rock, TX Metropolitan Statistical...     51
# 9380   Austin-Round Rock, TX Metropolitan Statistical...     52
# 9398   Austin-Round Rock, TX Metropolitan Statistical...     54
# 17277  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     21
# 17304  Boston-Cambridge-Quincy, MA-NH Metropolitan St...  31-33
# 17340  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     51
# 17349  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     52
# 17367  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     54
#
#                                                Industry      Filter  \
# 9308      Mining, quarrying, and oil and gas extraction  1:   Total
# 9335                                      Manufacturing  1:   Total
# 9371                                        Information  1:   Total
# 9380                              Finance and insurance  1:   Total
# 9398   Professional, scientific, and technical services  1:   Total
# 17277     Mining, quarrying, and oil and gas extraction  1:   Total
# 17304                                     Manufacturing  1:   Total
# 17340                                       Information  1:   Total
# 17349                             Finance and insurance  1:   Total
# 17367  Professional, scientific, and technical services  1:   Total
#
#       Employment Annual Payroll Establishments
# 9308       1,769        116,021            189
# 9335      34,928      2,009,837          1,217
# 9371      24,245      1,813,188            972
# 9380      33,102      2,162,166          2,950
# 9398      64,243      5,081,125          6,709
# 17277        448         28,094             47
# 17304    151,795      9,887,695          4,568
# 17340     83,961      7,687,682          2,777
# 17349    166,857     18,895,243          7,210
# 17367    220,311     21,082,177         17,155

# %% [markdown]
# # Data for 2011

# %%
#import data from csv files
file_jobs_2011=pd.read_csv("Idea1/business_2011.csv")
file_jobs_2011.head(1)
# Out:
#    FIPS   MSA CODE                              MSA DESCRIPTION CODE  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area   --
#
#   NAICS DESCRIPTION        SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0             Total  1:   Total             954                    1,034
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     10,165                   NaN                     G
#
#   ANNUAL PAYROLLL (1000) NOISE FLAG
# 0                378,700          G

# %%
file_jobs_2011_clean=file_jobs_2011.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                    ' SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishments',
                                                   'EMPLOYMENT': 'Employment',
                                                   'ANNUAL PAYROLLL (1000)': "Annual Payroll"})
file_jobs_2011_clean.head(1)
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
#
#   Industry      Filter NUMBER OF FIRMS Establishments Employment  \
# 0    Total  1:   Total             954          1,034     10,165
#
#   EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG Annual Payroll NOISE FLAG
# 0                   NaN                     G        378,700          G

# %%
jobs_2011=file_jobs_2011_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Employment', 'Annual Payroll', 'Establishments']]
jobs_2011.head(1)
# Out:
#                                     Metro Area NAICS Industry      Filter  \
# 0  Abbeville, LA Micropolitan Statistical Area    --    Total  1:   Total
#
#   Employment Annual Payroll Establishments
# 0     10,165        378,700          1,034

# %%
cities_2011=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       'Houston-Sugar Land-Baytown, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Northern New Jersey-Long Island, NY-NJ-PA Metropolitan Statistical']

industries_2011=['Mining, quarrying, and oil and gas extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and insurance', 
            'Professional, scientific, and technical services']
            
filters_2011=['1:   Total']

# %%
jobs_2011_cities=jobs_2011[jobs_2011['Metro Area'].isin(cities_2011)]
jobs_2011_ind=jobs_2011_cities[jobs_2011_cities['Industry'].isin(industries_2011)]
jobs_2011_filtered=jobs_2011_ind[jobs_2011_ind['Filter'].isin(filters_2011)]
jobs_2011_filtered.head(10)
#jobs_2008_ind.head()
# Out:
#                                               Metro Area  NAICS  \
# 9309   Austin-Round Rock, TX Metropolitan Statistical...     21
# 9336   Austin-Round Rock, TX Metropolitan Statistical...  31-33
# 9372   Austin-Round Rock, TX Metropolitan Statistical...     51
# 9381   Austin-Round Rock, TX Metropolitan Statistical...     52
# 9399   Austin-Round Rock, TX Metropolitan Statistical...     54
# 17303  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     21
# 17330  Boston-Cambridge-Quincy, MA-NH Metropolitan St...  31-33
# 17366  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     51
# 17375  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     52
# 17393  Boston-Cambridge-Quincy, MA-NH Metropolitan St...     54
#
#                                                Industry      Filter  \
# 9309      Mining, quarrying, and oil and gas extraction  1:   Total
# 9336                                      Manufacturing  1:   Total
# 9372                                        Information  1:   Total
# 9381                              Finance and insurance  1:   Total
# 9399   Professional, scientific, and technical services  1:   Total
# 17303     Mining, quarrying, and oil and gas extraction  1:   Total
# 17330                                     Manufacturing  1:   Total
# 17366                                       Information  1:   Total
# 17375                             Finance and insurance  1:   Total
# 17393  Professional, scientific, and technical services  1:   Total
#
#       Employment Annual Payroll Establishments
# 9309       2,073        139,238            206
# 9336      36,452      2,310,570          1,225
# 9372      24,060      1,784,095            990
# 9381      32,226      2,250,215          2,967
# 9399      64,489      5,216,742          6,897
# 17303        465         32,156             45
# 17330    150,141     10,652,314          4,487
# 17366     81,632      7,477,652          2,787
# 17375    167,074     20,047,142          7,119
# 17393    220,434     22,201,231         17,030

# %%
#import data from csv files
file_jobs_2012=pd.read_csv("Idea1/business_2012.csv")
file_jobs_2012.head()
# Out:
#    FIPS   MSA CODE          MSA DESCRIPTION  NAICS   CODE  NAICS DESCRIPTION  \
# 0            10100  Aberdeen, SD Micro Area             --             Total
# 1            10100  Aberdeen, SD Micro Area             --             Total
# 2            10100  Aberdeen, SD Micro Area             --             Total
# 3            10100  Aberdeen, SD Micro Area             --             Total
# 4            10100  Aberdeen, SD Micro Area             --             Total
#
#   ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0                 1:   Total           1,328                    1,408
# 1                   2:   0-4             674                      674
# 2                   3:   5-9             217                      217
# 3                 4:   10-19             137                      139
# 4                   5:   <20           1,028                    1,030
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     18,652                   NaN                     G
# 1      1,163                   NaN                     G
# 2      1,475                   NaN                     G
# 3      1,753                   NaN                     G
# 4      4,391                   NaN                     G
#
#   ANNUAL PAYROLL ($1,000) ANNUAL PAYROLL NOISE FLAG  \
# 0                 649,811                         G
# 1                  38,444                         G
# 2                  41,853                         G
# 3                  55,563                         G
# 4                 135,860                         G
#
#   ESTIMATED RECEIPTS ($1,000) ESTIMATED RECEIPTS NOISE FLAG
# 0                   6,562,426                             G
# 1                     264,661                             G
# 2                     276,775                             G
# 3                     392,579                             G
# 4                     934,015                             G

# %%
file_jobs_2012_clean=file_jobs_2012.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   ' NAICS   CODE ': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'ENTERPRISE EMPLOYMENT SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishment',
                                                    'EMPLOYMENT': "Employment",
                                                    'ANNUAL PAYROLL ($1,000)': "Payroll($1000)"
                                                   })
file_jobs_2012_clean.head()
# Out:
#    FIPS   MSA CODE               Metro Area NAICS Industry      Filter  \
# 0            10100  Aberdeen, SD Micro Area    --    Total  1:   Total
# 1            10100  Aberdeen, SD Micro Area    --    Total    2:   0-4
# 2            10100  Aberdeen, SD Micro Area    --    Total    3:   5-9
# 3            10100  Aberdeen, SD Micro Area    --    Total  4:   10-19
# 4            10100  Aberdeen, SD Micro Area    --    Total    5:   <20
#
#   NUMBER OF FIRMS Establishment Employment EMPLOYMENT RANGE FLAG  \
# 0           1,328         1,408     18,652                   NaN
# 1             674           674      1,163                   NaN
# 2             217           217      1,475                   NaN
# 3             137           139      1,753                   NaN
# 4           1,028         1,030      4,391                   NaN
#
#   EMPLOYMENT NOISE FLAG Payroll($1000) ANNUAL PAYROLL NOISE FLAG  \
# 0                     G        649,811                         G
# 1                     G         38,444                         G
# 2                     G         41,853                         G
# 3                     G         55,563                         G
# 4                     G        135,860                         G
#
#   ESTIMATED RECEIPTS ($1,000) ESTIMATED RECEIPTS NOISE FLAG
# 0                   6,562,426                             G
# 1                     264,661                             G
# 2                     276,775                             G
# 3                     392,579                             G
# 4                     934,015                             G

# %%
jobs_2012=file_jobs_2012_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Establishment', 'Employment', 'Payroll($1000)']]
jobs_2012.head()
# Out:
#                 Metro Area NAICS Industry      Filter Establishment  \
# 0  Aberdeen, SD Micro Area    --    Total  1:   Total         1,408
# 1  Aberdeen, SD Micro Area    --    Total    2:   0-4           674
# 2  Aberdeen, SD Micro Area    --    Total    3:   5-9           217
# 3  Aberdeen, SD Micro Area    --    Total  4:   10-19           139
# 4  Aberdeen, SD Micro Area    --    Total    5:   <20         1,030
#
#   Employment Payroll($1000)
# 0     18,652        649,811
# 1      1,163         38,444
# 2      1,475         41,853
# 3      1,753         55,563
# 4      4,391        135,860

# %%
cities_2012=['San Francisco-Oakland-Hayward, CA Metro Area',
       'Houston-The Woodlands-Sugar Land, TX Metro Area',
       'Austin-Round Rock, TX Metro Area',
       'Detroit-Warren-Dearborn, MI Metro Area',
       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area',
       'Boston-Cambridge-Newton, MA-NH Metro Area',
       'New York-Newark-Jersey City, NY-NJ-PA Metro Area']

industries_2012=['Mining, Quarrying, and Oil and Gas Extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2012=['1:   Total']

# %%
jobs_2012_cities=jobs_2012[jobs_2012['Metro Area'].isin(cities_2012)]
jobs_2012_ind=jobs_2012_cities[jobs_2012_cities['Industry'].isin(industries_2012)]
jobs_2012_filtered=jobs_2012_ind[jobs_2012_ind['Filter'].isin(filters_2012)]
jobs_2012_filtered.head()
# Out:
#                             Metro Area  NAICS  \
# 8615  Austin-Round Rock, TX Metro Area     21
# 8642  Austin-Round Rock, TX Metro Area  31-33
# 8678  Austin-Round Rock, TX Metro Area     51
# 8687  Austin-Round Rock, TX Metro Area     52
# 8705  Austin-Round Rock, TX Metro Area     54
#
#                                               Industry      Filter  \
# 8615     Mining, Quarrying, and Oil and Gas Extraction  1:   Total
# 8642                                     Manufacturing  1:   Total
# 8678                                       Information  1:   Total
# 8687                             Finance and Insurance  1:   Total
# 8705  Professional, Scientific, and Technical Services  1:   Total
#
#      Establishment Employment Payroll($1000)
# 8615           205      2,027        157,791
# 8642         1,298     37,421      2,384,511
# 8678         1,072     27,457      2,150,649
# 8687         3,232     34,212      2,622,786
# 8705         7,277     69,806      5,546,267

# %% [markdown]
# # Data for 2013

# %%
#import data from csv files
file_jobs_2013=pd.read_csv("Idea1/business_2013.csv")
file_jobs_2013.head()
# Out:
#    FIPS    CODE          MSA DESCRIPTION NAICS   CODE  NAICS DESCRIPTION  \
# 0         10100  Aberdeen, SD Micro Area            --             Total
# 1         10100  Aberdeen, SD Micro Area            --             Total
# 2         10100  Aberdeen, SD Micro Area            --             Total
# 3         10100  Aberdeen, SD Micro Area            --             Total
# 4         10100  Aberdeen, SD Micro Area            --             Total
#
#   ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0                 01:  Total           1,318                    1,396
# 1                   02:  0-4             655                      655
# 2                   03:  5-9             219                      219
# 3                 04:  10-19             144                      148
# 4                   05:  <20           1,018                    1,022
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     19,294                   NaN                     G
# 1      1,165                   NaN                     H
# 2      1,437                   NaN                     G
# 3      1,851                   NaN                     G
# 4      4,453                   NaN                     G
#
#   ANNUAL PAYROLL ($1,000) ANNUAL PAYROLL NOISE FLAG
# 0                 665,648                         G
# 1                  39,487                         G
# 2                  44,289                         G
# 3                  57,902                         G
# 4                 141,678                         G

# %%
file_jobs_2013_clean=file_jobs_2013.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'NAICS   CODE ': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'ENTERPRISE EMPLOYMENT SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishment',
                                                    'EMPLOYMENT': "Employment",
                                                    'ANNUAL PAYROLL ($1,000)': "Payroll($1000)"
                                                   })
file_jobs_2013_clean.head()
# Out:
#    FIPS    CODE               Metro Area NAICS Industry      Filter  \
# 0         10100  Aberdeen, SD Micro Area    --    Total  01:  Total
# 1         10100  Aberdeen, SD Micro Area    --    Total    02:  0-4
# 2         10100  Aberdeen, SD Micro Area    --    Total    03:  5-9
# 3         10100  Aberdeen, SD Micro Area    --    Total  04:  10-19
# 4         10100  Aberdeen, SD Micro Area    --    Total    05:  <20
#
#   NUMBER OF FIRMS Establishment Employment EMPLOYMENT RANGE FLAG  \
# 0           1,318         1,396     19,294                   NaN
# 1             655           655      1,165                   NaN
# 2             219           219      1,437                   NaN
# 3             144           148      1,851                   NaN
# 4           1,018         1,022      4,453                   NaN
#
#   EMPLOYMENT NOISE FLAG Payroll($1000) ANNUAL PAYROLL NOISE FLAG
# 0                     G        665,648                         G
# 1                     H         39,487                         G
# 2                     G         44,289                         G
# 3                     G         57,902                         G
# 4                     G        141,678                         G

# %%
jobs_2013=file_jobs_2013_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Establishment', 'Employment', 'Payroll($1000)']]
jobs_2013.head()
# Out:
#                 Metro Area NAICS Industry      Filter Establishment  \
# 0  Aberdeen, SD Micro Area    --    Total  01:  Total         1,396
# 1  Aberdeen, SD Micro Area    --    Total    02:  0-4           655
# 2  Aberdeen, SD Micro Area    --    Total    03:  5-9           219
# 3  Aberdeen, SD Micro Area    --    Total  04:  10-19           148
# 4  Aberdeen, SD Micro Area    --    Total    05:  <20         1,022
#
#   Employment Payroll($1000)
# 0     19,294        665,648
# 1      1,165         39,487
# 2      1,437         44,289
# 3      1,851         57,902
# 4      4,453        141,678

# %%
cities_2013=['San Francisco-Oakland-Hayward, CA Metro Area',
       'Houston-The Woodlands-Sugar Land, TX Metro Area',
       'Austin-Round Rock, TX Metro Area',
       'Detroit-Warren-Dearborn, MI Metro Area',
       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area',
       'Boston-Cambridge-Newton, MA-NH Metro Area',
       'New York-Newark-Jersey City, NY-NJ-PA Metro Area']

industries_2013=['Mining, Quarrying, and Oil and Gas Extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2013=['01:  Total']

# %%
jobs_2013_cities=jobs_2013[jobs_2013['Metro Area'].isin(cities_2013)]
jobs_2013_ind=jobs_2013_cities[jobs_2013_cities['Industry'].isin(industries_2013)]
jobs_2013_filtered=jobs_2013_ind[jobs_2013_ind['Filter'].isin(filters_2013)]
jobs_2013_filtered.head()
# Out:
#                             Metro Area  NAICS  \
# 8667  Austin-Round Rock, TX Metro Area     21
# 8694  Austin-Round Rock, TX Metro Area  31-33
# 8730  Austin-Round Rock, TX Metro Area     51
# 8739  Austin-Round Rock, TX Metro Area     52
# 8757  Austin-Round Rock, TX Metro Area     54
#
#                                               Industry      Filter  \
# 8667     Mining, Quarrying, and Oil and Gas Extraction  01:  Total
# 8694                                     Manufacturing  01:  Total
# 8730                                       Information  01:  Total
# 8739                             Finance and Insurance  01:  Total
# 8757  Professional, Scientific, and Technical Services  01:  Total
#
#      Establishment Employment Payroll($1000)
# 8667           206      2,205        174,279
# 8694         1,270     41,963      2,833,819
# 8730         1,073     28,043      2,195,644
# 8739         3,290     34,019      2,722,495
# 8757         7,591     74,214      6,403,975

# %% [markdown]
# # Data for 2014

# %%
#import data from csv files
file_jobs_2014=pd.read_csv("Idea1/business_2014.csv")
file_jobs_2014.head()
# Out:
#    FIPS    CODE          MSA DESCRIPTION NAICS   CODE  NAICS DESCRIPTION  \
# 0         10100  Aberdeen, SD Micro Area            --             Total
# 1         10100  Aberdeen, SD Micro Area            --             Total
# 2         10100  Aberdeen, SD Micro Area            --             Total
# 3         10100  Aberdeen, SD Micro Area            --             Total
# 4         10100  Aberdeen, SD Micro Area            --             Total
#
#   ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0                 01:  Total           1,328                    1,404
# 1                   02:  0-4             647                      647
# 2                   03:  5-9             217                      217
# 3                 04:  10-19             145                      148
# 4                   05:  <20           1,009                    1,012
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     19,575                   NaN                     G
# 1      1,106                   NaN                     G
# 2      1,438                   NaN                     G
# 3      1,811                   NaN                     G
# 4      4,355                   NaN                     G
#
#   ANNUAL PAYROLL ($1,000) ANNUAL PAYROLL NOISE FLAG  Unnamed: 12  Unnamed: 13  \
# 0                 696,915                         G          NaN          NaN
# 1                  37,038                         G          NaN          NaN
# 2                  44,117                         G          NaN          NaN
# 3                  57,742                         G          NaN          NaN
# 4                 138,897                         G          NaN          NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
file_jobs_2014_clean=file_jobs_2014.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'NAICS   CODE ': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'ENTERPRISE EMPLOYMENT SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishment',
                                                    'EMPLOYMENT': "Employment",
                                                    'ANNUAL PAYROLL ($1,000)': "Payroll($1000)"
                                                   })
file_jobs_2014_clean.head()
# Out:
#    FIPS    CODE               Metro Area NAICS Industry      Filter  \
# 0         10100  Aberdeen, SD Micro Area    --    Total  01:  Total
# 1         10100  Aberdeen, SD Micro Area    --    Total    02:  0-4
# 2         10100  Aberdeen, SD Micro Area    --    Total    03:  5-9
# 3         10100  Aberdeen, SD Micro Area    --    Total  04:  10-19
# 4         10100  Aberdeen, SD Micro Area    --    Total    05:  <20
#
#   NUMBER OF FIRMS Establishment Employment EMPLOYMENT RANGE FLAG  \
# 0           1,328         1,404     19,575                   NaN
# 1             647           647      1,106                   NaN
# 2             217           217      1,438                   NaN
# 3             145           148      1,811                   NaN
# 4           1,009         1,012      4,355                   NaN
#
#   EMPLOYMENT NOISE FLAG Payroll($1000) ANNUAL PAYROLL NOISE FLAG  Unnamed: 12  \
# 0                     G        696,915                         G          NaN
# 1                     G         37,038                         G          NaN
# 2                     G         44,117                         G          NaN
# 3                     G         57,742                         G          NaN
# 4                     G        138,897                         G          NaN
#
#    Unnamed: 13  Unnamed: 14
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
jobs_2014=file_jobs_2014_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Establishment', 'Employment', 'Payroll($1000)']]
jobs_2014.head()
# Out:
#                 Metro Area NAICS Industry      Filter Establishment  \
# 0  Aberdeen, SD Micro Area    --    Total  01:  Total         1,404
# 1  Aberdeen, SD Micro Area    --    Total    02:  0-4           647
# 2  Aberdeen, SD Micro Area    --    Total    03:  5-9           217
# 3  Aberdeen, SD Micro Area    --    Total  04:  10-19           148
# 4  Aberdeen, SD Micro Area    --    Total    05:  <20         1,012
#
#   Employment Payroll($1000)
# 0     19,575        696,915
# 1      1,106         37,038
# 2      1,438         44,117
# 3      1,811         57,742
# 4      4,355        138,897

# %%
cities_2014=['San Francisco-Oakland-Hayward, CA Metro Area',
       'Houston-The Woodlands-Sugar Land, TX Metro Area',
       'Austin-Round Rock, TX Metro Area',
       'Detroit-Warren-Dearborn, MI Metro Area',
       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area',
       'Boston-Cambridge-Newton, MA-NH Metro Area',
       'New York-Newark-Jersey City, NY-NJ-PA Metro Area']

industries_2014=['Mining, Quarrying, and Oil and Gas Extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2014=['01:  Total']

# %%
jobs_2014_cities=jobs_2014[jobs_2014['Metro Area'].isin(cities_2014)]
jobs_2014_ind=jobs_2014_cities[jobs_2014_cities['Industry'].isin(industries_2014)]
jobs_2014_filtered=jobs_2014_ind[jobs_2014_ind['Filter'].isin(filters_2014)]
jobs_2014_filtered.head()
# Out:
#                             Metro Area  NAICS  \
# 8661  Austin-Round Rock, TX Metro Area     21
# 8688  Austin-Round Rock, TX Metro Area  31-33
# 8724  Austin-Round Rock, TX Metro Area     51
# 8733  Austin-Round Rock, TX Metro Area     52
# 8751  Austin-Round Rock, TX Metro Area     54
#
#                                               Industry      Filter  \
# 8661     Mining, Quarrying, and Oil and Gas Extraction  01:  Total
# 8688                                     Manufacturing  01:  Total
# 8724                                       Information  01:  Total
# 8733                             Finance and Insurance  01:  Total
# 8751  Professional, Scientific, and Technical Services  01:  Total
#
#      Establishment Employment Payroll($1000)
# 8661           216      2,440        202,590
# 8688         1,299     42,592      2,824,143
# 8724         1,129     31,857      2,998,574
# 8733         3,217     34,508      2,853,432
# 8751         7,984     78,996      6,963,470

# %% [markdown]
# # Data for 2015

# %%
#import data from csv files
file_jobs_2015=pd.read_csv("Idea1/business_2015.csv", encoding = "ISO-8859-1")
file_jobs_2015.head()
# Out:
#    FIPS    CODE          MSA DESCRIPTION NAICS   CODE  NAICS DESCRIPTION  \
# 0         10100  Aberdeen, SD Micro Area            --             Total
# 1         10100  Aberdeen, SD Micro Area            --             Total
# 2         10100  Aberdeen, SD Micro Area            --             Total
# 3         10100  Aberdeen, SD Micro Area            --             Total
# 4         10100  Aberdeen, SD Micro Area            --             Total
#
#   ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0                 01:  Total           1,337                    1,411
# 1                   02:  0-4             655                      656
# 2                   03:  5-9             224                      224
# 3                 04:  10-19             142                      145
# 4                   05:  <20           1,021                    1,025
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     19,778                   NaN                     G
# 1      1,105                   NaN                     H
# 2      1,518                   NaN                     G
# 3      1,815                   NaN                     G
# 4      4,438                   NaN                     G
#
#   ANNUAL PAYROLL ($1,000) ANNUAL PAYROLL NOISE FLAG  Unnamed: 12  Unnamed: 13  \
# 0                 748,033                         H          NaN          NaN
# 1                  39,854                         G          NaN          NaN
# 2                  48,227                         G          NaN          NaN
# 3                  62,092                         G          NaN          NaN
# 4                 150,173                         G          NaN          NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
file_jobs_2015_clean=file_jobs_2015.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'NAICS   CODE ': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'ENTERPRISE EMPLOYMENT SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishment',
                                                    'EMPLOYMENT': "Employment",
                                                    'ANNUAL PAYROLL ($1,000)': "Payroll($1000)"
                                                   })
file_jobs_2015_clean.head()
# Out:
#    FIPS    CODE               Metro Area NAICS Industry      Filter  \
# 0         10100  Aberdeen, SD Micro Area    --    Total  01:  Total
# 1         10100  Aberdeen, SD Micro Area    --    Total    02:  0-4
# 2         10100  Aberdeen, SD Micro Area    --    Total    03:  5-9
# 3         10100  Aberdeen, SD Micro Area    --    Total  04:  10-19
# 4         10100  Aberdeen, SD Micro Area    --    Total    05:  <20
#
#   NUMBER OF FIRMS Establishment Employment EMPLOYMENT RANGE FLAG  \
# 0           1,337         1,411     19,778                   NaN
# 1             655           656      1,105                   NaN
# 2             224           224      1,518                   NaN
# 3             142           145      1,815                   NaN
# 4           1,021         1,025      4,438                   NaN
#
#   EMPLOYMENT NOISE FLAG Payroll($1000) ANNUAL PAYROLL NOISE FLAG  Unnamed: 12  \
# 0                     G        748,033                         H          NaN
# 1                     H         39,854                         G          NaN
# 2                     G         48,227                         G          NaN
# 3                     G         62,092                         G          NaN
# 4                     G        150,173                         G          NaN
#
#    Unnamed: 13  Unnamed: 14
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
jobs_2015=file_jobs_2015_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Establishment', 'Employment', 'Payroll($1000)']]
jobs_2015.head()
# Out:
#                 Metro Area NAICS Industry      Filter Establishment  \
# 0  Aberdeen, SD Micro Area    --    Total  01:  Total         1,411
# 1  Aberdeen, SD Micro Area    --    Total    02:  0-4           656
# 2  Aberdeen, SD Micro Area    --    Total    03:  5-9           224
# 3  Aberdeen, SD Micro Area    --    Total  04:  10-19           145
# 4  Aberdeen, SD Micro Area    --    Total    05:  <20         1,025
#
#   Employment Payroll($1000)
# 0     19,778        748,033
# 1      1,105         39,854
# 2      1,518         48,227
# 3      1,815         62,092
# 4      4,438        150,173

# %%
cities_2015=['San Francisco-Oakland-Hayward, CA Metro Area',
       'Houston-The Woodlands-Sugar Land, TX Metro Area',
       'Austin-Round Rock, TX Metro Area',
       'Detroit-Warren-Dearborn, MI Metro Area',
       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area',
       'Boston-Cambridge-Newton, MA-NH Metro Area',
       'New York-Newark-Jersey City, NY-NJ-PA Metro Area']

industries_2015=['Mining, Quarrying, and Oil and Gas Extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2015=['01:  Total']

# %%
jobs_2015_cities=jobs_2015[jobs_2015['Metro Area'].isin(cities_2015)]
jobs_2015_ind=jobs_2015_cities[jobs_2015_cities['Industry'].isin(industries_2015)]
jobs_2015_filtered=jobs_2015_ind[jobs_2015_ind['Filter'].isin(filters_2015)]
jobs_2015_filtered.head()
# Out:
#                             Metro Area  NAICS  \
# 8637  Austin-Round Rock, TX Metro Area     21
# 8664  Austin-Round Rock, TX Metro Area  31-33
# 8700  Austin-Round Rock, TX Metro Area     51
# 8709  Austin-Round Rock, TX Metro Area     52
# 8727  Austin-Round Rock, TX Metro Area     54
#
#                                               Industry      Filter  \
# 8637     Mining, Quarrying, and Oil and Gas Extraction  01:  Total
# 8664                                     Manufacturing  01:  Total
# 8700                                       Information  01:  Total
# 8709                             Finance and Insurance  01:  Total
# 8727  Professional, Scientific, and Technical Services  01:  Total
#
#      Establishment Employment Payroll($1000)
# 8637           209      2,468        175,677
# 8664         1,338     40,823      2,635,077
# 8700         1,184     34,346      3,227,622
# 8709         3,305     36,508      3,142,947
# 8727         8,433     85,828      7,959,042

# %% [markdown]
# # Data for 2016

# %%
#import data from csv files
file_jobs_2016=pd.read_csv("Idea1/business_2016.csv", encoding = "ISO-8859-1")
file_jobs_2016.head()
# Out:
#    FIPS    CODE          MSA DESCRIPTION NAICS   CODE  NAICS DESCRIPTION  \
# 0         10100  Aberdeen, SD Micro Area            --             Total
# 1         10100  Aberdeen, SD Micro Area            --             Total
# 2         10100  Aberdeen, SD Micro Area            --             Total
# 3         10100  Aberdeen, SD Micro Area            --             Total
# 4         10100  Aberdeen, SD Micro Area            --             Total
#
#   ENTERPRISE EMPLOYMENT SIZE NUMBER OF FIRMS NUMBER OF ESTABLISHMENTS  \
# 0                 01:  Total           1,342                    1,418
# 1                   02:  0-4             663                      663
# 2                   03:  5-9             216                      216
# 3                 04:  10-19             139                      143
# 4                   05:  <20           1,018                    1,022
#
#   EMPLOYMENT EMPLOYMENT RANGE FLAG EMPLOYMENT NOISE FLAG  \
# 0     19,533                   NaN                     G
# 1      1,076                   NaN                     H
# 2      1,442                   NaN                     G
# 3      1,759                   NaN                     G
# 4      4,277                   NaN                     G
#
#   ANNUAL PAYROLL ($1,000) ANNUAL PAYROLL NOISE FLAG  Unnamed: 12  Unnamed: 13  \
# 0                 746,190                         H          NaN          NaN
# 1                  41,114                         G          NaN          NaN
# 2                  45,082                         G          NaN          NaN
# 3                  58,959                         G          NaN          NaN
# 4                 145,155                         G          NaN          NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
file_jobs_2016_clean=file_jobs_2016.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'NAICS   CODE ': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'ENTERPRISE EMPLOYMENT SIZE': 'Filter',
                                                   'NUMBER OF ESTABLISHMENTS': 'Establishment',
                                                    'EMPLOYMENT': "Employment",
                                                    'ANNUAL PAYROLL ($1,000)': "Payroll($1000)"
                                                   })
file_jobs_2016_clean.head()
# Out:
#    FIPS    CODE               Metro Area NAICS Industry      Filter  \
# 0         10100  Aberdeen, SD Micro Area    --    Total  01:  Total
# 1         10100  Aberdeen, SD Micro Area    --    Total    02:  0-4
# 2         10100  Aberdeen, SD Micro Area    --    Total    03:  5-9
# 3         10100  Aberdeen, SD Micro Area    --    Total  04:  10-19
# 4         10100  Aberdeen, SD Micro Area    --    Total    05:  <20
#
#   NUMBER OF FIRMS Establishment Employment EMPLOYMENT RANGE FLAG  \
# 0           1,342         1,418     19,533                   NaN
# 1             663           663      1,076                   NaN
# 2             216           216      1,442                   NaN
# 3             139           143      1,759                   NaN
# 4           1,018         1,022      4,277                   NaN
#
#   EMPLOYMENT NOISE FLAG Payroll($1000) ANNUAL PAYROLL NOISE FLAG  Unnamed: 12  \
# 0                     G        746,190                         H          NaN
# 1                     H         41,114                         G          NaN
# 2                     G         45,082                         G          NaN
# 3                     G         58,959                         G          NaN
# 4                     G        145,155                         G          NaN
#
#    Unnamed: 13  Unnamed: 14
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
jobs_2016=file_jobs_2016_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Establishment', 'Employment', 'Payroll($1000)']]
jobs_2016.head()
# Out:
#                 Metro Area NAICS Industry      Filter Establishment  \
# 0  Aberdeen, SD Micro Area    --    Total  01:  Total         1,418
# 1  Aberdeen, SD Micro Area    --    Total    02:  0-4           663
# 2  Aberdeen, SD Micro Area    --    Total    03:  5-9           216
# 3  Aberdeen, SD Micro Area    --    Total  04:  10-19           143
# 4  Aberdeen, SD Micro Area    --    Total    05:  <20         1,022
#
#   Employment Payroll($1000)
# 0     19,533        746,190
# 1      1,076         41,114
# 2      1,442         45,082
# 3      1,759         58,959
# 4      4,277        145,155

# %%
cities_2016=['San Francisco-Oakland-Hayward, CA Metro Area',
       'Houston-The Woodlands-Sugar Land, TX Metro Area',
       'Austin-Round Rock, TX Metro Area',
       'Detroit-Warren-Dearborn, MI Metro Area',
       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area',
       'Boston-Cambridge-Newton, MA-NH Metro Area',
       'New York-Newark-Jersey City, NY-NJ-PA Metro Area']

industries_2016=['Mining, Quarrying, and Oil and Gas Extraction', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters_2016=['01:  Total']

# %%
jobs_2016_cities=jobs_2016[jobs_2016['Metro Area'].isin(cities_2016)]
jobs_2016_ind=jobs_2016_cities[jobs_2016_cities['Industry'].isin(industries_2016)]
jobs_2016_filtered=jobs_2016_ind[jobs_2016_ind['Filter'].isin(filters_2016)]
jobs_2016_filtered.head()
# Out:
#                             Metro Area  NAICS  \
# 8627  Austin-Round Rock, TX Metro Area     21
# 8654  Austin-Round Rock, TX Metro Area  31-33
# 8690  Austin-Round Rock, TX Metro Area     51
# 8699  Austin-Round Rock, TX Metro Area     52
# 8717  Austin-Round Rock, TX Metro Area     54
#
#                                               Industry      Filter  \
# 8627     Mining, Quarrying, and Oil and Gas Extraction  01:  Total
# 8654                                     Manufacturing  01:  Total
# 8690                                       Information  01:  Total
# 8699                             Finance and Insurance  01:  Total
# 8717  Professional, Scientific, and Technical Services  01:  Total
#
#      Establishment Employment Payroll($1000)
# 8627           187      2,138        155,541
# 8654         1,376     40,296      2,664,829
# 8690         1,205     35,538      3,214,259
# 8699         3,579     37,432      3,297,696
# 8717         8,805    102,096      9,848,185
