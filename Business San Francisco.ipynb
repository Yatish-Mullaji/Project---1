# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

url = "https://data.sfgov.org/resource/g8m3-pdis.json"

# %%
response = requests.get(url).json() 
response
# Out:
# [{'ttxid': '0000024-02-999',
#   'certificate_number': '0000024',
#   'ownership_name': 'Eastman Kodak Co',
#   'dba_name': 'Eastman Kodak Co',
#   'full_business_address': '343 State St',
#   'city': 'Rochester',
#   'state': 'NY',
#   'business_zip': '14650',
#   'dba_start_date': '2003-01-01T00:00:00.000',
#   'location_start_date': '2003-01-01T00:00:00.000',
#   'mailing_address_1': '343 State St',
#   'mail_city': 'Rochester',
#   'mail_zipcode': '14650',
#   'mail_state': 'NY',
#   'naic_code': '3100-3399',
#   'naic_code_description': 'Manufacturing',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-77.619386, 43.161276]}},
#  {'ttxid': '0000028-02-001',
#   'certificate_number': '0000028',
#   'ownership_name': 'Ferrando Louise',
#   'dba_name': '3101 Laguna Apts',
#   'full_business_address': '3101 Laguna St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94123',
#   'dba_start_date': '1993-09-30T00:00:00.000',
#   'location_start_date': '1993-09-30T00:00:00.000',
#   'mailing_address_1': '2799 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94115',
#   'mail_state': 'CA',
#   'naic_code': '5300-5399',
#   'naic_code_description': 'Real Estate and Rental and Leasing Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Marina',
#   'location': {'type': 'Point', 'coordinates': [-122.430996, 37.799823]}},
#  {'ttxid': '0000052-01-001',
#   'certificate_number': '0000052',
#   'ownership_name': 'Ideal Novak Corp',
#   'dba_name': 'Ideal Novak Corp',
#   'full_business_address': '8 Mendosa Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94116',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '8 Mendosa Ave',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94116',
#   'mail_state': 'CA',
#   'naic_code': '5300-5399',
#   'naic_code_description': 'Real Estate and Rental and Leasing Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '7',
#   'neighborhoods_analysis_boundaries': 'West of Twin Peaks',
#   'location': {'type': 'Point', 'coordinates': [-122.465074, 37.748926]}},
#  {'ttxid': '0000071-01-001',
#   'certificate_number': '0000071',
#   'ownership_name': 'Tournahu George L',
#   'dba_name': 'Tournahu Arms',
#   'full_business_address': '1842 Jefferson St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94123',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2013-12-31T00:00:00.000',
#   'mailing_address_1': '4444 Geary Blvd Ste 100',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.442997, 37.804734]}},
#  {'ttxid': '0000071-02-001',
#   'certificate_number': '0000071',
#   'ownership_name': 'Tournahu George L',
#   'dba_name': '3301 Broderick Apartments',
#   'full_business_address': '3301 Broderick St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94123',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1988-05-01T00:00:00.000',
#   'location_end_date': '2013-12-31T00:00:00.000',
#   'mailing_address_1': '4444 Geary Blvd Ste 100',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Marina',
#   'location': {'type': 'Point', 'coordinates': [-122.444757, 37.800876]}},
#  {'ttxid': '0000071-02-003',
#   'certificate_number': '0000071',
#   'ownership_name': 'Tournahu George L',
#   'dba_name': '3301 Broderick Apartments',
#   'full_business_address': '3301 Broderick St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94123',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1988-05-01T00:00:00.000',
#   'location_end_date': '2013-12-31T00:00:00.000',
#   'mailing_address_1': '4444 Geary Blvd Ste 100',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Marina',
#   'location': {'type': 'Point', 'coordinates': [-122.444757, 37.800876]}},
#  {'ttxid': '0000071-03-001',
#   'certificate_number': '0000071',
#   'ownership_name': 'Tournahu George L',
#   'dba_name': '1840-42 Jefferson St',
#   'full_business_address': '1840 Jefferson St #42',
#   'city': 'San+francisco',
#   'state': 'CA',
#   'business_zip': '94123',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1991-10-07T00:00:00.000',
#   'mailing_address_1': '4444 Geary Blvd Ste 100',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'parking_tax': True,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.442794, 37.804759]}},
#  {'ttxid': '0000086-01-001',
#   'certificate_number': '0000086',
#   'ownership_name': 'Harry D Som Living Trust',
#   'dba_name': '1601 Grant Apts',
#   'full_business_address': '1601 Grant Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2016-06-30T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2016-06-30T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.407812, 37.801724]}},
#  {'ttxid': '0000086-02-002',
#   'certificate_number': '0000086',
#   'ownership_name': 'Harry D Som Living Trust',
#   'dba_name': '1601 Grant Parking',
#   'full_business_address': '1601 Grant Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2016-06-30T00:00:00.000',
#   'location_start_date': '2013-01-01T00:00:00.000',
#   'location_end_date': '2016-06-30T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.407812, 37.801724]}},
#  {'ttxid': '0000188-01-001',
#   'certificate_number': '0000188',
#   'ownership_name': 'Abbett Elec Corp',
#   'dba_name': 'Abbett Elec Corp',
#   'full_business_address': '1850 Bryant St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94110',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '1850 Bryant St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94110',
#   'mail_state': 'CA',
#   'naic_code': '2300-2399',
#   'naic_code_description': 'Construction',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D26',
#   'lic_code_description': 'Station Tanks - Above Ground',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'location': {'type': 'Point', 'coordinates': [-122.410307, 37.76378]}},
#  {'ttxid': '0000189-02-001',
#   'certificate_number': '0000189',
#   'ownership_name': 'Tc Mcmechen Inc',
#   'dba_name': 'Abbey Carpet',
#   'full_business_address': '2900 Geary Blvd',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2012-07-27T00:00:00.000',
#   'mailing_address_1': '2900 Geary Blvd',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Presidio Heights',
#   'location': {'type': 'Point', 'coordinates': [-122.450433, 37.782133]}},
#  {'ttxid': '0000189-03-001',
#   'certificate_number': '0000189',
#   'ownership_name': 'Tc Mcmechen Inc',
#   'dba_name': 'Abbey Carpet Of San Francisco',
#   'full_business_address': '2900 Geary Blvd',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2013-10-01T00:00:00.000',
#   'mailing_address_1': '2900 Geary Blvd',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Presidio Heights',
#   'location': {'type': 'Point', 'coordinates': [-122.450433, 37.782133]}},
#  {'ttxid': '0000205-01-001',
#   'certificate_number': '0000205',
#   'ownership_name': 'Abc Auto Parts',
#   'dba_name': 'Abc Auto Parts',
#   'full_business_address': '1650 Davidson Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94124',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '1650 Davidson Ave',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94124',
#   'mail_state': 'CA',
#   'naic_code': '4200-4299',
#   'naic_code_description': 'Wholesale Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D02 D03 D20 P19',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Bayview Hunters Point',
#   'location': {'type': 'Point', 'coordinates': [-122.392421, 37.746192]}},
#  {'ttxid': '0000216-01-001',
#   'certificate_number': '0000216',
#   'ownership_name': 'Sasser Jr Jake',
#   'dba_name': 'Abc Insurance',
#   'full_business_address': '1727 Oakdale Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94124',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2018-06-30T00:00:00.000',
#   'location_start_date': '2002-10-24T00:00:00.000',
#   'location_end_date': '2018-06-30T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Bayview Hunters Point',
#   'location': {'type': 'Point', 'coordinates': [-122.393059, 37.736139]}},
#  {'ttxid': '0000216-02-001',
#   'certificate_number': '0000216',
#   'ownership_name': 'Sasser Jr Jake',
#   'dba_name': 'J & E Construction',
#   'full_business_address': '1727 Oakdale Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94124',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2018-06-30T00:00:00.000',
#   'location_start_date': '1999-08-27T00:00:00.000',
#   'location_end_date': '2018-06-30T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Bayview Hunters Point',
#   'location': {'type': 'Point', 'coordinates': [-122.393059, 37.736139]}},
#  {'ttxid': '0000224-01-001',
#   'certificate_number': '0000224',
#   'ownership_name': 'Abc Window Contractors Inc',
#   'dba_name': 'Abc Window Contractors Inc',
#   'full_business_address': '811 Cesar Chavez St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94124',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2018-07-01T00:00:00.000',
#   'location_start_date': '1997-09-29T00:00:00.000',
#   'location_end_date': '2015-10-31T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Bayview Hunters Point',
#   'location': {'type': 'Point', 'coordinates': [-122.386099, 37.75034]}},
#  {'ttxid': '0000244-01-001',
#   'certificate_number': '0000244',
#   'ownership_name': 'Crown Building Maintenance Co',
#   'dba_name': 'Able Building Maintenance Co',
#   'full_business_address': '868 Folsom St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '868 Folsom St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94107',
#   'mail_state': 'CA',
#   'naic_code': '5600-5699',
#   'naic_code_description': 'Administrative and Support Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'location': {'type': 'Point', 'coordinates': [-122.402797, 37.780746]}},
#  {'ttxid': '0000244-02-001',
#   'certificate_number': '0000244',
#   'ownership_name': 'Crown Building Maintenance Co',
#   'dba_name': 'Able Services',
#   'full_business_address': '868 Folsom St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2005-04-01T00:00:00.000',
#   'mailing_address_1': '868 Folsom St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94107',
#   'mail_state': 'CA',
#   'naic_code': '5600-5699',
#   'naic_code_description': 'Administrative and Support Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'location': {'type': 'Point', 'coordinates': [-122.402797, 37.780746]}},
#  {'ttxid': '0000265-01-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '79 New Montgomery St Fl 3',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2004-03-01T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D03 D39',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.400776, 37.7877]}},
#  {'ttxid': '0000265-04-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Acad Art College Supply Store',
#   'full_business_address': '79 New Montgomery St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1993-02-01T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'POS01',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.400776, 37.7877]}},
#  {'ttxid': '0000265-06-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '410 Bush St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94108',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1994-01-28T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D02 D03 D19',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.404484, 37.790697]}},
#  {'ttxid': '0000265-06-002',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '2225 Jerrold Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94124',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2009-05-29T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D14 D18 D19 D26',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Bayview Hunters Point',
#   'location': {'type': 'Point', 'coordinates': [-122.400812, 37.74525]}},
#  {'ttxid': '0000265-06-003',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '180 New Montgomery St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1995-04-28T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D03 D04 D39',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.399502, 37.786634]}},
#  {'ttxid': '0000265-06-004',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '540 Powell St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94108',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1994-01-28T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D04',
#   'lic_code_description': 'Places Of Public Assembly & Open-Air Assembly',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.408673, 37.789736]}},
#  {'ttxid': '0000265-06-005',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '460 Townsend St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2009-10-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Mission Bay',
#   'location': {'type': 'Point', 'coordinates': [-122.398633, 37.774234]}},
#  {'ttxid': '0000265-06-006',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '1835 Van Ness Ave #49',
#   'city': 'San+francisco',
#   'state': 'CA',
#   'business_zip': '94109',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1998-06-09T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D03 D05 D10 D19 D31',
#   'lic_code_description': 'Multiple',
#   'location': {'type': 'Point', 'coordinates': [-122.422943, 37.792972]}},
#  {'ttxid': '0000265-06-007',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '620 Sutter St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2005-08-11T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'H56 HHH',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Nob Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.410677, 37.788972]}},
#  {'ttxid': '0000265-06-008',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '655 Sutter St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1999-03-01T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'H60 HHH',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Nob Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.41109, 37.788919]}},
#  {'ttxid': '0000265-07-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '1055 Pine St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94109',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'HHH',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Nob Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.413156, 37.790564]}},
#  {'ttxid': '0000265-08-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '121 Wisconsin St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Mission Bay',
#   'location': {'type': 'Point', 'coordinates': [-122.39975, 37.765733]}},
#  {'ttxid': '0000265-09-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '150 Hayes St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2012-01-01T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'location': {'type': 'Point', 'coordinates': [-122.418822, 37.777396]}},
#  {'ttxid': '0000265-10-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '2300 Stockton St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.410549, 37.807161]}},
#  {'ttxid': '0000265-11-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '2801 Leavenworth St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-05-23T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D03 D19 D39',
#   'lic_code_description': 'Multiple',
#   'location': {'type': 'Point', 'coordinates': [-122.418926, 37.807088]}},
#  {'ttxid': '0000265-12-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '466 Townsend St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D26',
#   'lic_code_description': 'Station Tanks - Above Ground',
#   'location': {'type': 'Point', 'coordinates': [-122.399076, 37.773883]}},
#  {'ttxid': '0000265-13-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '491 Post St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D04',
#   'lic_code_description': 'Places Of Public Assembly & Open-Air Assembly',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'location': {'type': 'Point', 'coordinates': [-122.409734, 37.788127]}},
#  {'ttxid': '0000265-14-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '601 Brannan St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D03 D26 D37',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Mission Bay',
#   'location': {'type': 'Point', 'coordinates': [-122.399103, 37.776302]}},
#  {'ttxid': '0000265-15-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '625 Polk St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-08-15T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D03 D31',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'location': {'type': 'Point', 'coordinates': [-122.419041, 37.782393]}},
#  {'ttxid': '0000265-16-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '631 Howard St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'location_end_date': '2013-08-31T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.398792, 37.786347]}},
#  {'ttxid': '0000265-17-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '688 Sutter St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Nob Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.411745, 37.788834]}},
#  {'ttxid': '0000265-18-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '700 Montgomery St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2013-01-01T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'location': {'type': 'Point', 'coordinates': [-122.40335, 37.795699]}},
#  {'ttxid': '0000265-19-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '701 Chestnut St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-02-11T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Russian Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.41492, 37.803547]}},
#  {'ttxid': '0000265-20-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '860 Sutter St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94109',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'HHH',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Nob Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.411407, 37.788878]}},
#  {'ttxid': '0000265-21-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '60 Federal St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'D26',
#   'lic_code_description': 'Station Tanks - Above Ground',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.392413, 37.783211]}},
#  {'ttxid': '0000265-22-001',
#   'certificate_number': '0000265',
#   'ownership_name': 'Stephens Institute Inc',
#   'dba_name': 'Academy Of Art University',
#   'full_business_address': '740 Taylor St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94108',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-01-02T00:00:00.000',
#   'mailing_address_1': '79 New Montgomery St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94105',
#   'mail_state': 'CA',
#   'naic_code': '6100-6299',
#   'naic_code_description': 'Private Education and Health Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Nob Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.41202, 37.789316]}},
#  {'ttxid': '0000286-01-001',
#   'certificate_number': '0000286',
#   'ownership_name': 'Ace Boiler & Welding Co Inc',
#   'dba_name': 'Ace Boiler & Welding Co Inc',
#   'full_business_address': '601 19th St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2018-06-30T00:00:00.000',
#   'location_start_date': '1995-01-01T00:00:00.000',
#   'location_end_date': '2018-06-30T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Potrero Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.388981, 37.761755]}},
#  {'ttxid': '0000368-01-001',
#   'certificate_number': '0000368',
#   'ownership_name': 'Acoustical Consultants Inc',
#   'dba_name': 'Acoustical Consultants Inc',
#   'full_business_address': '150 California St 3rd Flr',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2018-06-30T00:00:00.000',
#   'location_start_date': '2004-08-16T00:00:00.000',
#   'location_end_date': '2018-06-30T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.398442, 37.793407]}},
#  {'ttxid': '0000422-01-001',
#   'certificate_number': '0000422',
#   'ownership_name': 'Kurt S. Adler Inc.',
#   'dba_name': 'Adler Kurt S Inc',
#   'full_business_address': '680 Eighth Street 157',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94103',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2017-09-20T00:00:00.000',
#   'location_start_date': '2011-01-01T00:00:00.000',
#   'location_end_date': '2017-09-20T00:00:00.000',
#   'naic_code': '4200-4299',
#   'naic_code_description': 'Wholesale Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'location': {'type': 'Point', 'coordinates': [-122.404476, 37.770475]}},
#  {'ttxid': '0000424-01-001',
#   'certificate_number': '0000424',
#   'ownership_name': 'Ebk Enterprise Et Al',
#   'dba_name': 'Floral Supply Syndicate',
#   'full_business_address': '670 Brannan St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': 'Po Box 1305',
#   'mail_city': 'Camarillo',
#   'mail_zipcode': '93011',
#   'mail_state': 'CA',
#   'naic_code': '4200-4299',
#   'naic_code_description': 'Wholesale Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'location': {'type': 'Point', 'coordinates': [-122.400344, 37.775325]}},
#  {'ttxid': '0000424-01-002',
#   'certificate_number': '0000424',
#   'ownership_name': 'Ebk Enterprise Et Al',
#   'dba_name': 'Floral Supply Syndicate',
#   'full_business_address': '649 Brannan St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94158',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2011-09-16T00:00:00.000',
#   'mailing_address_1': 'Po Box 1305',
#   'mail_city': 'Camarillo',
#   'mail_zipcode': '93011',
#   'mail_state': 'CA',
#   'naic_code': '4200-4299',
#   'naic_code_description': 'Wholesale Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Mission Bay',
#   'location': {'type': 'Point', 'coordinates': [-122.40003, 37.775573]}},
#  {'ttxid': '0000429-01-001',
#   'certificate_number': '0000429',
#   'ownership_name': 'Federal Auto Parks Inc',
#   'dba_name': 'Federal Auto Parks Inc',
#   'full_business_address': '530 Turk St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94102',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2014-06-15T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2014-06-15T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'location': {'type': 'Point', 'coordinates': [-122.417994, 37.782293]}},
#  {'ttxid': '0000481-01-001',
#   'certificate_number': '0000481',
#   'ownership_name': 'Agentours Inc',
#   'dba_name': 'Agentours Inc',
#   'full_business_address': '126 West Portal Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94127',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '126 West Portal Ave',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94127',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '7',
#   'neighborhoods_analysis_boundaries': 'West of Twin Peaks',
#   'location': {'type': 'Point', 'coordinates': [-122.46731, 37.739525]}},
#  {'ttxid': '0000482-01-001',
#   'certificate_number': '0000482',
#   'ownership_name': 'Fugazi Travel Agency, Inc.',
#   'dba_name': 'Fugazi Travel Agency, Inc.',
#   'full_business_address': '170 Grant Ave 4th Fl',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94108',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2009-02-01T00:00:00.000',
#   'location_end_date': '2015-08-31T00:00:00.000',
#   'mailing_address_1': '345 California St Ste 160',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.405174, 37.788511]}},
#  {'ttxid': '0000482-02-001',
#   'certificate_number': '0000482',
#   'ownership_name': 'Fugazi Travel Agency, Inc.',
#   'dba_name': 'La Collezione',
#   'full_business_address': '400 Sansome St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1997-07-01T00:00:00.000',
#   'location_end_date': '2015-08-31T00:00:00.000',
#   'mailing_address_1': '345 California St Ste 160',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'location': {'type': 'Point', 'coordinates': [-122.40134, 37.793982]}},
#  {'ttxid': '0000482-03-001',
#   'certificate_number': '0000482',
#   'ownership_name': 'Fugazi Travel Agency, Inc.',
#   'dba_name': 'Anaconda Adventures',
#   'full_business_address': '400 Sansome St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1997-07-01T00:00:00.000',
#   'location_end_date': '2015-08-31T00:00:00.000',
#   'mailing_address_1': '345 California St Ste 160',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'location': {'type': 'Point', 'coordinates': [-122.40134, 37.793982]}},
#  {'ttxid': '0000482-04-001',
#   'certificate_number': '0000482',
#   'ownership_name': 'Fugazi Travel Agency, Inc.',
#   'dba_name': 'Radio Travel',
#   'full_business_address': '400 Sansome St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1998-11-01T00:00:00.000',
#   'location_end_date': '2015-08-31T00:00:00.000',
#   'mailing_address_1': '345 California St Ste 160',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'location': {'type': 'Point', 'coordinates': [-122.40134, 37.793982]}},
#  {'ttxid': '0000482-05-001',
#   'certificate_number': '0000482',
#   'ownership_name': 'Fugazi Travel Agency, Inc.',
#   'dba_name': 'Sea Level',
#   'full_business_address': '400 Sansome St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1999-05-04T00:00:00.000',
#   'location_end_date': '2015-08-31T00:00:00.000',
#   'mailing_address_1': '345 California St Ste 160',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'location': {'type': 'Point', 'coordinates': [-122.40134, 37.793982]}},
#  {'ttxid': '0000484-01-001',
#   'certificate_number': '0000484',
#   'ownership_name': 'Agid Hyman D',
#   'dba_name': 'Agid Hyman D',
#   'full_business_address': '452 Gellert Dr',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94132',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2017-05-06T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2017-05-06T00:00:00.000',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '7',
#   'neighborhoods_analysis_boundaries': 'Sunset/Parkside',
#   'location': {'type': 'Point', 'coordinates': [-122.48987, 37.730494]}},
#  {'ttxid': '0000553-01-001',
#   'certificate_number': '0000553',
#   'ownership_name': 'Wong William V Etal',
#   'dba_name': 'Akron Meat Market',
#   'full_business_address': '3325 20th St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94110',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2017-12-31T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2017-12-31T00:00:00.000',
#   'naic_code': '4200-4299',
#   'naic_code_description': 'Wholesale Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'location': {'type': 'Point', 'coordinates': [-122.415292, 37.758859]}},
#  {'ttxid': '0000631-03-001',
#   'certificate_number': '0000631',
#   'ownership_name': 'Aon Risk Services Inc Of N Cal',
#   'dba_name': 'Aon Risk Services Inc Of N Cal',
#   'full_business_address': '199 Fremont St #1500',
#   'city': 'San+francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2009-07-28T00:00:00.000',
#   'mailing_address_1': '1100 Reynolds Blvd',
#   'mail_city': 'Winston Salem',
#   'mail_zipcode': '27105',
#   'mail_state': 'NC',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.395309, 37.789371]}},
#  {'ttxid': '0000668-01-001',
#   'certificate_number': '0000668',
#   'ownership_name': 'Alioto F Co Inc',
#   'dba_name': 'F Alioto Fish Co',
#   'full_business_address': '440 Jefferson St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94109',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '440 Jefferson St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94109',
#   'mail_state': 'CA',
#   'naic_code': '4200-4299',
#   'naic_code_description': 'Wholesale Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'lic': 'WM18 WM21 WM30',
#   'lic_code_description': 'Multiple',
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Russian Hill',
#   'location': {'type': 'Point', 'coordinates': [-122.419621, 37.807739]}},
#  {'ttxid': '0000670-01-001',
#   'certificate_number': '0000670',
#   'ownership_name': 'F & A Properties',
#   'dba_name': 'Alioto Frank & Anthony',
#   'full_business_address': '155 Jefferson St #100',
# ...
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Western Addition',
#   'location': {'type': 'Point', 'coordinates': [-122.424566, 37.784704]}},
#  {'ttxid': '0015229-01-001',
#   'certificate_number': '0015229',
#   'ownership_name': 'Kaplan Mclaughlin Diaz',
#   'dba_name': 'Kaplan Mclaughlin Diaz',
#   'full_business_address': '222 Vallejo St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2018-09-10T00:00:00.000',
#   'mailing_address_1': '417 Montgomery St 200 Ste',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.401728, 37.799467]}},
#  {'ttxid': '0015229-04-001',
#   'certificate_number': '0015229',
#   'ownership_name': 'Kaplan Mclaughlin Diaz',
#   'dba_name': 'Kmd',
#   'full_business_address': '222 Vallejo St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1995-12-22T00:00:00.000',
#   'location_end_date': '2018-09-10T00:00:00.000',
#   'mailing_address_1': '417 Montgomery St 200 Ste',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.401728, 37.799467]}},
#  {'ttxid': '0015229-05-001',
#   'certificate_number': '0015229',
#   'ownership_name': 'Kaplan Mclaughlin Diaz',
#   'dba_name': 'Kmd Justice',
#   'full_business_address': '222 Vallejo St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1997-01-01T00:00:00.000',
#   'location_end_date': '2018-09-10T00:00:00.000',
#   'mailing_address_1': '417 Montgomery St 200 Ste',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.401728, 37.799467]}},
#  {'ttxid': '0015229-06-001',
#   'certificate_number': '0015229',
#   'ownership_name': 'Kaplan Mclaughlin Diaz',
#   'dba_name': 'Kmd Architects',
#   'full_business_address': '222 Vallejo St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94111',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2004-01-01T00:00:00.000',
#   'location_end_date': '2018-09-10T00:00:00.000',
#   'mailing_address_1': '417 Montgomery St 200 Ste',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.401728, 37.799467]}},
#  {'ttxid': '0015231-01-001',
#   'certificate_number': '0015231',
#   'ownership_name': 'Kaplans Surplus-Sport Good In',
#   'dba_name': 'Kaplans Surplus-Sport Good Inc',
#   'full_business_address': '1055 Market St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94103',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2014-03-12T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2014-03-12T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'location': {'type': 'Point', 'coordinates': [-122.411578, 37.781228]}},
#  {'ttxid': '0015256-01-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': 'Karpman Stephen',
#   'full_business_address': '4333 California St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Inner Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.463858, 37.785085]}},
#  {'ttxid': '0015256-02-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': '3267-3273 25th St Apts',
#   'full_business_address': '3267 25th St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94110',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1971-01-01T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'location': {'type': 'Point', 'coordinates': [-122.415432, 37.750813]}},
#  {'ttxid': '0015256-04-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': '751 38th Ave Apts',
#   'full_business_address': '751 38th Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94121',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1976-04-22T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Outer Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.498323, 37.774723]}},
#  {'ttxid': '0015256-05-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': 'Domestic Violence Trtmnt Svcs',
#   'full_business_address': '4333 California St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2003-10-24T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Inner Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.463858, 37.785085]}},
#  {'ttxid': '0015256-06-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': 'Sexual Offenders Treatmnt Svcs',
#   'full_business_address': '4333 California St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2003-10-24T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Inner Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.463858, 37.785085]}},
#  {'ttxid': '0015256-07-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': 'Transactional Analysis Institu',
#   'full_business_address': '4333 California St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2003-10-24T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Inner Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.463858, 37.785085]}},
#  {'ttxid': '0015256-08-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': 'Alcoholic/coalc Trmnt&trng Ins',
#   'full_business_address': '4333 California St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2003-10-24T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Inner Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.463858, 37.785085]}},
#  {'ttxid': '0015256-09-001',
#   'certificate_number': '0015256',
#   'ownership_name': 'Karpman Stephen',
#   'dba_name': 'Pacific Bay Rentals',
#   'full_business_address': '4333 California St',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2003-10-24T00:00:00.000',
#   'mailing_address_1': '4333 California St',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94118',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Inner Richmond',
#   'location': {'type': 'Point', 'coordinates': [-122.463858, 37.785085]}},
#  {'ttxid': '0015258-01-001',
#   'certificate_number': '0015258',
#   'ownership_name': 'Lautze & Lautze',
#   'dba_name': 'Lautze & Lautze',
#   'full_business_address': '303 2nd St #950',
#   'city': 'San+francisco',
#   'state': 'CA',
#   'business_zip': '94107',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '1 Montgomery St 1700',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94104',
#   'mail_state': 'CA',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.395892, 37.784886]}},
#  {'ttxid': '0015260-01-001',
#   'certificate_number': '0015260',
#   'ownership_name': 'Guttmann & Blaevoet',
#   'dba_name': 'Guttmann & Blaevoet',
#   'full_business_address': '2351 Powell St Ste',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '2002-10-23T00:00:00.000',
#   'mailing_address_1': '2351 Powell St Ste',
#   'mail_city': 'San Francisco',
#   'mail_zipcode': '94133',
#   'mail_state': 'CA',
#   'naic_code': '5400-5499',
#   'naic_code_description': 'Professional, Scientific, and Technical Services',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'location': {'type': 'Point', 'coordinates': [-122.412013, 37.806072]}},
#  {'ttxid': '0015273-01-001',
#   'certificate_number': '0015273',
#   'ownership_name': 'Katz Communications Inc',
#   'dba_name': 'Katz Communications Inc',
#   'full_business_address': '100 Spear St #1900',
#   'city': 'San+francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'mailing_address_1': '125 W 55th St',
#   'mail_city': 'New York',
#   'mail_zipcode': '10019',
#   'mail_state': 'NY',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.393839, 37.792355]}},
#  {'ttxid': '0015273-02-001',
#   'certificate_number': '0015273',
#   'ownership_name': 'Katz Communications Inc',
#   'dba_name': 'Sentry Radio Sales',
#   'full_business_address': '100 Spear St #1900',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94105',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'location_start_date': '1996-01-03T00:00:00.000',
#   'mailing_address_1': '125 W 55th St',
#   'mail_city': 'New York',
#   'mail_zipcode': '10019',
#   'mail_state': 'NY',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'location': {'type': 'Point', 'coordinates': [-122.393839, 37.792355]}},
#  {'ttxid': '0015281-01-001',
#   'certificate_number': '0015281',
#   'ownership_name': 'Kaufers Catholic Supplies',
#   'dba_name': 'Kaufers Religious Supplies',
#   'full_business_address': '1455 Custer Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94124',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2015-01-31T00:00:00.000',
#   'location_start_date': '2007-05-11T00:00:00.000',
#   'location_end_date': '2015-01-31T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Bayview Hunters Point',
#   'location': {'type': 'Point', 'coordinates': [-122.388432, 37.744878]}},
#  {'ttxid': '0015285-01-001',
#   'certificate_number': '0015285',
#   'ownership_name': 'Kaufman Stephen',
#   'dba_name': 'Kaufman Stephen',
#   'full_business_address': '3905 Sacramento St 205',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94118',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2014-09-01T00:00:00.000',
#   'location_start_date': '1994-07-01T00:00:00.000',
#   'location_end_date': '2014-09-01T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Presidio Heights',
#   'location': {'type': 'Point', 'coordinates': [-122.457212, 37.786892]}},
#  {'ttxid': '0015310-01-001',
#   'certificate_number': '0015310',
#   'ownership_name': 'Kayes Footwear Inc',
#   'dba_name': 'Kayes Footwear Inc',
#   'full_business_address': '1043 Grant Ave',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94133',
#   'dba_start_date': '1968-10-01T00:00:00.000',
#   'dba_end_date': '2018-05-31T00:00:00.000',
#   'location_start_date': '1968-10-01T00:00:00.000',
#   'location_end_date': '2018-05-31T00:00:00.000',
#   'naic_code': '4400-4599',
#   'naic_code_description': 'Retail Trade',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'location': {'type': 'Point', 'coordinates': [-122.406732, 37.796402]}},
#  {'ttxid': '0015352-02-002',
#   'certificate_number': '0015352',
#   'ownership_name': 'Bocci Jc Barry Mcnamara Etal',
#   'dba_name': 'St Francis Opthalmology Group',
#   'full_business_address': '2001 Union St 480',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'business_zip': '94123',
#   'dba_start_date': '1993-01-02T00:00:00.000',
#   'dba_end_date': '2016-04-02T00:00:00.000',
#   'location_start_date': '1993-01-02T00:00:00.000',
#   'location_end_date': '2016-04-02T00:00:00.000',
#   'parking_tax': False,
#   'transient_occupancy_tax': False,
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Marina',
#   'location': {'type': 'Point', 'coordinates': [-122.432519, 37.79746]}}]

# %%
table = pd.DataFrame(response)
table
# Out:
#     business_corridor business_zip certificate_number           city  \
# 0                 NaN        14650            0000024      Rochester
# 1                 NaN        94123            0000028  San Francisco
# 2                 NaN        94116            0000052  San Francisco
# 3                 NaN        94123            0000071  San Francisco
# 4                 NaN        94123            0000071  San Francisco
# 5                 NaN        94123            0000071  San Francisco
# 6                 NaN        94123            0000071  San+francisco
# 7                 NaN        94133            0000086  San Francisco
# 8                 NaN        94133            0000086  San Francisco
# 9                 NaN        94110            0000188  San Francisco
# 10                NaN        94118            0000189  San Francisco
# 11                NaN        94118            0000189  San Francisco
# 12                NaN        94124            0000205  San Francisco
# 13                NaN        94124            0000216  San Francisco
# 14                NaN        94124            0000216  San Francisco
# 15                NaN        94124            0000224  San Francisco
# 16                NaN        94107            0000244  San Francisco
# 17                NaN        94107            0000244  San Francisco
# 18                NaN        94105            0000265  San Francisco
# 19                NaN        94105            0000265  San Francisco
# 20                NaN        94108            0000265  San Francisco
# 21                NaN        94124            0000265  San Francisco
# 22                NaN        94105            0000265  San Francisco
# 23                NaN        94108            0000265  San Francisco
# 24                NaN        94107            0000265  San Francisco
# 25                NaN        94109            0000265  San+francisco
# 26                NaN        94102            0000265  San Francisco
# 27                NaN        94102            0000265  San Francisco
# 28                NaN        94109            0000265  San Francisco
# 29                NaN        94107            0000265  San Francisco
# ..                ...          ...                ...            ...
# 970               NaN        94117            0015031  San Francisco
# 971               NaN        94117            0015031  San Francisco
# 972               NaN        94102            0015032  San Francisco
# 973               NaN        94111            0015037  San Francisco
# 974               NaN        94124            0015048  San Francisco
# 975               NaN        94109            0015092  San Francisco
# 976               NaN        94121            0015150  San Francisco
# 977               NaN        94109            0015188  San Francisco
# 978               NaN        94109            0015188  San Francisco
# 979               NaN        94111            0015229  San Francisco
# 980               NaN        94111            0015229  San Francisco
# 981               NaN        94111            0015229  San Francisco
# 982               NaN        94111            0015229  San Francisco
# 983               NaN        94103            0015231  San Francisco
# 984               NaN        94118            0015256  San Francisco
# 985               NaN        94110            0015256  San Francisco
# 986               NaN        94121            0015256  San Francisco
# 987               NaN        94118            0015256  San Francisco
# 988               NaN        94118            0015256  San Francisco
# 989               NaN        94118            0015256  San Francisco
# 990               NaN        94118            0015256  San Francisco
# 991               NaN        94118            0015256  San Francisco
# 992               NaN        94107            0015258  San+francisco
# 993               NaN        94133            0015260  San Francisco
# 994               NaN        94105            0015273  San+francisco
# 995               NaN        94105            0015273  San Francisco
# 996               NaN        94124            0015281  San Francisco
# 997               NaN        94118            0015285  San Francisco
# 998               NaN        94133            0015310  San Francisco
# 999               NaN        94123            0015352  San Francisco
#
#                 dba_end_date                        dba_name  \
# 0                        NaN                Eastman Kodak Co
# 1                        NaN                3101 Laguna Apts
# 2                        NaN                Ideal Novak Corp
# 3                        NaN                   Tournahu Arms
# 4                        NaN       3301 Broderick Apartments
# 5                        NaN       3301 Broderick Apartments
# 6                        NaN            1840-42 Jefferson St
# 7    2016-06-30T00:00:00.000                 1601 Grant Apts
# 8    2016-06-30T00:00:00.000              1601 Grant Parking
# 9                        NaN                Abbett Elec Corp
# 10                       NaN                    Abbey Carpet
# 11                       NaN   Abbey Carpet Of San Francisco
# 12                       NaN                  Abc Auto Parts
# 13   2018-06-30T00:00:00.000                   Abc Insurance
# 14   2018-06-30T00:00:00.000              J & E Construction
# 15   2018-07-01T00:00:00.000      Abc Window Contractors Inc
# 16                       NaN    Able Building Maintenance Co
# 17                       NaN                   Able Services
# 18                       NaN       Academy Of Art University
# 19                       NaN   Acad Art College Supply Store
# 20                       NaN       Academy Of Art University
# 21                       NaN       Academy Of Art University
# 22                       NaN       Academy Of Art University
# 23                       NaN       Academy Of Art University
# 24                       NaN       Academy Of Art University
# 25                       NaN       Academy Of Art University
# 26                       NaN       Academy Of Art University
# 27                       NaN       Academy Of Art University
# 28                       NaN       Academy Of Art University
# 29                       NaN       Academy Of Art University
# ..                       ...                             ...
# 970                      NaN         150-156 Steiner St Bldg
# 971                      NaN          114 Steiner Street Apt
# 972  2018-12-31T00:00:00.000        Jones Schiller & Co, Llp
# 973                      NaN        Wylie Jones Furniture Co
# 974                      NaN                 Sam Jordans Bar
# 975                      NaN                    Jug Shop Inc
# 976  2018-12-31T00:00:00.000                  K & G Jewelers
# 977                      NaN               Kahn Zel R & Sons
# 978                      NaN         355 Brannan St Building
# 979                      NaN          Kaplan Mclaughlin Diaz
# 980                      NaN                             Kmd
# 981                      NaN                     Kmd Justice
# 982                      NaN                  Kmd Architects
# 983  2014-03-12T00:00:00.000  Kaplans Surplus-Sport Good Inc
# 984                      NaN                 Karpman Stephen
# 985                      NaN          3267-3273 25th St Apts
# 986                      NaN               751 38th Ave Apts
# 987                      NaN   Domestic Violence Trtmnt Svcs
# 988                      NaN  Sexual Offenders Treatmnt Svcs
# 989                      NaN  Transactional Analysis Institu
# 990                      NaN  Alcoholic/coalc Trmnt&trng Ins
# 991                      NaN             Pacific Bay Rentals
# 992                      NaN                 Lautze & Lautze
# 993                      NaN             Guttmann & Blaevoet
# 994                      NaN         Katz Communications Inc
# 995                      NaN              Sentry Radio Sales
# 996  2015-01-31T00:00:00.000      Kaufers Religious Supplies
# 997  2014-09-01T00:00:00.000                 Kaufman Stephen
# 998  2018-05-31T00:00:00.000              Kayes Footwear Inc
# 999  2016-04-02T00:00:00.000   St Francis Opthalmology Group
#
#               dba_start_date      full_business_address                  lic  \
# 0    2003-01-01T00:00:00.000               343 State St                  NaN
# 1    1993-09-30T00:00:00.000             3101 Laguna St                  NaN
# 2    1968-10-01T00:00:00.000              8 Mendosa Ave                  NaN
# 3    1968-10-01T00:00:00.000          1842 Jefferson St                  NaN
# 4    1968-10-01T00:00:00.000          3301 Broderick St                  NaN
# 5    1968-10-01T00:00:00.000          3301 Broderick St                  NaN
# 6    1968-10-01T00:00:00.000      1840 Jefferson St #42                  NaN
# 7    1968-10-01T00:00:00.000             1601 Grant Ave                  NaN
# 8    1968-10-01T00:00:00.000             1601 Grant Ave                  NaN
# 9    1968-10-01T00:00:00.000             1850 Bryant St                  D26
# 10   1968-10-01T00:00:00.000            2900 Geary Blvd                  NaN
# 11   1968-10-01T00:00:00.000            2900 Geary Blvd                  NaN
# 12   1968-10-01T00:00:00.000          1650 Davidson Ave      D02 D03 D20 P19
# 13   1968-10-01T00:00:00.000           1727 Oakdale Ave                  NaN
# 14   1968-10-01T00:00:00.000           1727 Oakdale Ave                  NaN
# 15   1968-10-01T00:00:00.000        811 Cesar Chavez St                  NaN
# 16   1968-10-01T00:00:00.000              868 Folsom St                  NaN
# 17   1968-10-01T00:00:00.000              868 Folsom St                  NaN
# 18   1968-10-01T00:00:00.000  79 New Montgomery St Fl 3              D03 D39
# 19   1968-10-01T00:00:00.000       79 New Montgomery St                POS01
# 20   1968-10-01T00:00:00.000                410 Bush St          D02 D03 D19
# 21   1968-10-01T00:00:00.000           2225 Jerrold Ave      D14 D18 D19 D26
# 22   1968-10-01T00:00:00.000      180 New Montgomery St          D03 D04 D39
# 23   1968-10-01T00:00:00.000              540 Powell St                  D04
# 24   1968-10-01T00:00:00.000            460 Townsend St                  NaN
# 25   1968-10-01T00:00:00.000      1835 Van Ness Ave #49  D03 D05 D10 D19 D31
# 26   1968-10-01T00:00:00.000              620 Sutter St              H56 HHH
# 27   1968-10-01T00:00:00.000              655 Sutter St              H60 HHH
# 28   1968-10-01T00:00:00.000               1055 Pine St                  HHH
# 29   1968-10-01T00:00:00.000           121 Wisconsin St                  NaN
# ..                       ...                        ...                  ...
# 970  2005-12-31T00:00:00.000             150 Steiner St                  NaN
# 971  2005-12-31T00:00:00.000             114 Steiner St                  NaN
# 972  1968-10-01T00:00:00.000        507 Polk St Ste 300                  NaN
# 973  1968-10-01T00:00:00.000             72a Lombard St                  NaN
# 974  1968-10-01T00:00:00.000                4004 3rd St                  H25
# 975  1968-10-01T00:00:00.000           1590 Pacific Ave    H31 H73 H87 POS01
# 976  1968-10-01T00:00:00.000            5520 Geary Blvd                  NaN
# 977  1968-10-01T00:00:00.000      1200 Gough St Ste 900                  NaN
# 978  1968-10-01T00:00:00.000      1200 Gough St Ste 900                  NaN
# 979  1968-10-01T00:00:00.000             222 Vallejo St                  NaN
# 980  1968-10-01T00:00:00.000             222 Vallejo St                  NaN
# 981  1968-10-01T00:00:00.000             222 Vallejo St                  NaN
# 982  1968-10-01T00:00:00.000             222 Vallejo St                  NaN
# 983  1968-10-01T00:00:00.000             1055 Market St                  NaN
# 984  1968-10-01T00:00:00.000         4333 California St                  NaN
# 985  1968-10-01T00:00:00.000               3267 25th St                  NaN
# 986  1968-10-01T00:00:00.000               751 38th Ave                  NaN
# 987  1968-10-01T00:00:00.000         4333 California St                  NaN
# 988  1968-10-01T00:00:00.000         4333 California St                  NaN
# 989  1968-10-01T00:00:00.000         4333 California St                  NaN
# 990  1968-10-01T00:00:00.000         4333 California St                  NaN
# 991  1968-10-01T00:00:00.000         4333 California St                  NaN
# 992  1968-10-01T00:00:00.000            303 2nd St #950                  NaN
# 993  1968-10-01T00:00:00.000         2351 Powell St Ste                  NaN
# 994  1968-10-01T00:00:00.000         100 Spear St #1900                  NaN
# 995  1968-10-01T00:00:00.000         100 Spear St #1900                  NaN
# 996  1968-10-01T00:00:00.000            1455 Custer Ave                  NaN
# 997  1968-10-01T00:00:00.000     3905 Sacramento St 205                  NaN
# 998  1968-10-01T00:00:00.000             1043 Grant Ave                  NaN
# 999  1993-01-02T00:00:00.000          2001 Union St 480                  NaN
#
#                               lic_code_description       ...        \
# 0                                              NaN       ...
# 1                                              NaN       ...
# 2                                              NaN       ...
# 3                                              NaN       ...
# 4                                              NaN       ...
# 5                                              NaN       ...
# 6                                              NaN       ...
# 7                                              NaN       ...
# 8                                              NaN       ...
# 9                     Station Tanks - Above Ground       ...
# 10                                             NaN       ...
# 11                                             NaN       ...
# 12                                        Multiple       ...
# 13                                             NaN       ...
# 14                                             NaN       ...
# 15                                             NaN       ...
# 16                                             NaN       ...
# 17                                             NaN       ...
# 18                                        Multiple       ...
# 19                                        Multiple       ...
# 20                                        Multiple       ...
# 21                                        Multiple       ...
# 22                                        Multiple       ...
# 23   Places Of Public Assembly & Open-Air Assembly       ...
# 24                                             NaN       ...
# 25                                        Multiple       ...
# 26                                        Multiple       ...
# 27                                        Multiple       ...
# 28                                             NaN       ...
# 29                                             NaN       ...
# ..                                             ...       ...
# 970                                            NaN       ...
# 971                                            NaN       ...
# 972                                            NaN       ...
# 973                                            NaN       ...
# 974                  Restaurant 1,000 - 2,000 Sqft       ...
# 975                                       Multiple       ...
# 976                                            NaN       ...
# 977                                            NaN       ...
# 978                                            NaN       ...
# 979                                            NaN       ...
# 980                                            NaN       ...
# 981                                            NaN       ...
# 982                                            NaN       ...
# 983                                            NaN       ...
# 984                                            NaN       ...
# 985                                            NaN       ...
# 986                                            NaN       ...
# 987                                            NaN       ...
# 988                                            NaN       ...
# 989                                            NaN       ...
# 990                                            NaN       ...
# 991                                            NaN       ...
# 992                                            NaN       ...
# 993                                            NaN       ...
# 994                                            NaN       ...
# 995                                            NaN       ...
# 996                                            NaN       ...
# 997                                            NaN       ...
# 998                                            NaN       ...
# 999                                            NaN       ...
#
#              mailing_address_1  naic_code  \
# 0                 343 State St  3100-3399
# 1           2799 California St  5300-5399
# 2                8 Mendosa Ave  5300-5399
# 3      4444 Geary Blvd Ste 100        NaN
# 4      4444 Geary Blvd Ste 100        NaN
# 5      4444 Geary Blvd Ste 100        NaN
# 6      4444 Geary Blvd Ste 100        NaN
# 7                          NaN        NaN
# 8                          NaN        NaN
# 9               1850 Bryant St  2300-2399
# 10             2900 Geary Blvd  4400-4599
# 11             2900 Geary Blvd  4400-4599
# 12           1650 Davidson Ave  4200-4299
# 13                         NaN        NaN
# 14                         NaN        NaN
# 15                         NaN        NaN
# 16               868 Folsom St  5600-5699
# 17               868 Folsom St  5600-5699
# 18        79 New Montgomery St  6100-6299
# 19        79 New Montgomery St  6100-6299
# 20        79 New Montgomery St  6100-6299
# 21        79 New Montgomery St  6100-6299
# 22        79 New Montgomery St  6100-6299
# 23        79 New Montgomery St  6100-6299
# 24        79 New Montgomery St  6100-6299
# 25        79 New Montgomery St  6100-6299
# 26        79 New Montgomery St  6100-6299
# 27        79 New Montgomery St  6100-6299
# 28        79 New Montgomery St  6100-6299
# 29        79 New Montgomery St  6100-6299
# ..                         ...        ...
# 970              Po Box 591540  5300-5399
# 971              Po Box 591540  5300-5399
# 972                        NaN  5400-5499
# 973              2155 25th Ave  4400-4599
# 974    0000 Undeliverable Mail  7220-7229
# 975           1590 Pacific Ave  4400-4599
# 976                        NaN  4400-4599
# 977      1200 Gough St Ste 900  5300-5399
# 978      1200 Gough St Ste 900  5300-5399
# 979  417 Montgomery St 200 Ste  5400-5499
# 980  417 Montgomery St 200 Ste  5400-5499
# 981  417 Montgomery St 200 Ste  5400-5499
# 982  417 Montgomery St 200 Ste  5400-5499
# 983                        NaN        NaN
# 984         4333 California St  5400-5499
# 985         4333 California St  5400-5499
# 986         4333 California St  5400-5499
# 987         4333 California St  5400-5499
# 988         4333 California St  5400-5499
# 989         4333 California St  5400-5499
# 990         4333 California St  5400-5499
# 991         4333 California St  5400-5499
# 992       1 Montgomery St 1700        NaN
# 993         2351 Powell St Ste  5400-5499
# 994              125 W 55th St        NaN
# 995              125 W 55th St        NaN
# 996                        NaN        NaN
# 997                        NaN        NaN
# 998                        NaN  4400-4599
# 999                        NaN        NaN
#
#                                 naic_code_description  \
# 0                                       Manufacturing
# 1         Real Estate and Rental and Leasing Services
# 2         Real Estate and Rental and Leasing Services
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                        Construction
# 10                                       Retail Trade
# 11                                       Retail Trade
# 12                                    Wholesale Trade
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                Administrative and Support Services
# 17                Administrative and Support Services
# 18              Private Education and Health Services
# 19              Private Education and Health Services
# 20              Private Education and Health Services
# 21              Private Education and Health Services
# 22              Private Education and Health Services
# 23              Private Education and Health Services
# 24              Private Education and Health Services
# 25              Private Education and Health Services
# 26              Private Education and Health Services
# 27              Private Education and Health Services
# 28              Private Education and Health Services
# 29              Private Education and Health Services
# ..                                                ...
# 970       Real Estate and Rental and Leasing Services
# 971       Real Estate and Rental and Leasing Services
# 972  Professional, Scientific, and Technical Services
# 973                                      Retail Trade
# 974                                     Food Services
# 975                                      Retail Trade
# 976                                      Retail Trade
# 977       Real Estate and Rental and Leasing Services
# 978       Real Estate and Rental and Leasing Services
# 979  Professional, Scientific, and Technical Services
# 980  Professional, Scientific, and Technical Services
# 981  Professional, Scientific, and Technical Services
# 982  Professional, Scientific, and Technical Services
# 983                                               NaN
# 984  Professional, Scientific, and Technical Services
# 985  Professional, Scientific, and Technical Services
# 986  Professional, Scientific, and Technical Services
# 987  Professional, Scientific, and Technical Services
# 988  Professional, Scientific, and Technical Services
# 989  Professional, Scientific, and Technical Services
# 990  Professional, Scientific, and Technical Services
# 991  Professional, Scientific, and Technical Services
# 992                                               NaN
# 993  Professional, Scientific, and Technical Services
# 994                                               NaN
# 995                                               NaN
# 996                                               NaN
# 997                                               NaN
# 998                                      Retail Trade
# 999                                               NaN
#
#     neighborhoods_analysis_boundaries                         ownership_name  \
# 0                                 NaN                       Eastman Kodak Co
# 1                              Marina                        Ferrando Louise
# 2                  West of Twin Peaks                       Ideal Novak Corp
# 3                                 NaN                      Tournahu George L
# 4                              Marina                      Tournahu George L
# 5                              Marina                      Tournahu George L
# 6                                 NaN                      Tournahu George L
# 7                         North Beach               Harry D Som Living Trust
# 8                         North Beach               Harry D Som Living Trust
# 9                             Mission                       Abbett Elec Corp
# 10                   Presidio Heights                        Tc Mcmechen Inc
# 11                   Presidio Heights                        Tc Mcmechen Inc
# 12              Bayview Hunters Point                         Abc Auto Parts
# 13              Bayview Hunters Point                         Sasser Jr Jake
# 14              Bayview Hunters Point                         Sasser Jr Jake
# 15              Bayview Hunters Point             Abc Window Contractors Inc
# 16                    South of Market          Crown Building Maintenance Co
# 17                    South of Market          Crown Building Maintenance Co
# 18     Financial District/South Beach                 Stephens Institute Inc
# 19     Financial District/South Beach                 Stephens Institute Inc
# 20     Financial District/South Beach                 Stephens Institute Inc
# 21              Bayview Hunters Point                 Stephens Institute Inc
# 22     Financial District/South Beach                 Stephens Institute Inc
# 23     Financial District/South Beach                 Stephens Institute Inc
# 24                        Mission Bay                 Stephens Institute Inc
# 25                                NaN                 Stephens Institute Inc
# 26                           Nob Hill                 Stephens Institute Inc
# 27                           Nob Hill                 Stephens Institute Inc
# 28                           Nob Hill                 Stephens Institute Inc
# 29                        Mission Bay                 Stephens Institute Inc
# ..                                ...                                    ...
# 970                      Hayes Valley                        Pedersen Gordon
# 971                      Hayes Valley                        Pedersen Gordon
# 972                        Tenderloin           Jones Schiller & Company Llp
# 973    Financial District/South Beach                      Jones Elias Wylie
# 974             Bayview Hunters Point  Sam Jordan Of California Catering Inc
# 975                      Russian Hill                           Jug Shop Inc
# 976                               NaN                           Honma George
# 977                  Western Addition                  Zel R Kahn & Sons Inc
# 978                  Western Addition                  Zel R Kahn & Sons Inc
# 979                               NaN                 Kaplan Mclaughlin Diaz
# 980                               NaN                 Kaplan Mclaughlin Diaz
# 981                               NaN                 Kaplan Mclaughlin Diaz
# 982                               NaN                 Kaplan Mclaughlin Diaz
# 983                   South of Market          Kaplans Surplus-Sport Good In
# 984                    Inner Richmond                        Karpman Stephen
# 985                           Mission                        Karpman Stephen
# 986                    Outer Richmond                        Karpman Stephen
# 987                    Inner Richmond                        Karpman Stephen
# 988                    Inner Richmond                        Karpman Stephen
# 989                    Inner Richmond                        Karpman Stephen
# 990                    Inner Richmond                        Karpman Stephen
# 991                    Inner Richmond                        Karpman Stephen
# 992                               NaN                        Lautze & Lautze
# 993                       North Beach                    Guttmann & Blaevoet
# 994                               NaN                Katz Communications Inc
# 995                               NaN                Katz Communications Inc
# 996             Bayview Hunters Point              Kaufers Catholic Supplies
# 997                  Presidio Heights                        Kaufman Stephen
# 998                         Chinatown                     Kayes Footwear Inc
# 999                            Marina           Bocci Jc Barry Mcnamara Etal
#
#     parking_tax state supervisor_district transient_occupancy_tax  \
# 0         False    NY                 NaN                   False
# 1         False    CA                   2                   False
# 2         False    CA                   7                   False
# 3         False    CA                 NaN                   False
# 4         False    CA                   2                   False
# 5         False    CA                   2                   False
# 6          True    CA                 NaN                   False
# 7         False    CA                   3                   False
# 8         False    CA                   3                   False
# 9         False    CA                   9                   False
# 10        False    CA                   2                   False
# 11        False    CA                   2                   False
# 12        False    CA                  10                   False
# 13        False    CA                  10                   False
# 14        False    CA                  10                   False
# 15        False    CA                  10                   False
# 16        False    CA                   6                   False
# 17        False    CA                   6                   False
# 18        False    CA                   6                   False
# 19        False    CA                   6                   False
# 20        False    CA                   3                   False
# 21        False    CA                  10                   False
# 22        False    CA                   6                   False
# 23        False    CA                   3                   False
# 24        False    CA                   6                   False
# 25        False    CA                 NaN                   False
# 26        False    CA                   3                   False
# 27        False    CA                   3                   False
# 28        False    CA                   3                   False
# 29        False    CA                  10                   False
# ..          ...   ...                 ...                     ...
# 970       False    CA                   5                   False
# 971       False    CA                   5                   False
# 972       False    CA                   6                   False
# 973       False    CA                   3                   False
# 974       False    CA                  10                   False
# 975       False    CA                   3                   False
# 976       False    CA                 NaN                   False
# 977       False    CA                   5                   False
# 978       False    CA                   5                   False
# 979       False    CA                 NaN                   False
# 980       False    CA                 NaN                   False
# 981       False    CA                 NaN                   False
# 982       False    CA                 NaN                   False
# 983       False    CA                   6                   False
# 984       False    CA                   1                   False
# 985       False    CA                   9                   False
# 986       False    CA                   1                   False
# 987       False    CA                   1                   False
# 988       False    CA                   1                   False
# 989       False    CA                   1                   False
# 990       False    CA                   1                   False
# 991       False    CA                   1                   False
# 992       False    CA                 NaN                   False
# 993       False    CA                   3                   False
# 994       False    CA                 NaN                   False
# 995       False    CA                 NaN                   False
# 996       False    CA                  10                   False
# 997       False    CA                   2                   False
# 998       False    CA                   3                   False
# 999       False    CA                   2                   False
#
#               ttxid
# 0    0000024-02-999
# 1    0000028-02-001
# 2    0000052-01-001
# 3    0000071-01-001
# 4    0000071-02-001
# 5    0000071-02-003
# 6    0000071-03-001
# 7    0000086-01-001
# 8    0000086-02-002
# 9    0000188-01-001
# 10   0000189-02-001
# 11   0000189-03-001
# 12   0000205-01-001
# 13   0000216-01-001
# 14   0000216-02-001
# 15   0000224-01-001
# 16   0000244-01-001
# 17   0000244-02-001
# 18   0000265-01-001
# 19   0000265-04-001
# 20   0000265-06-001
# 21   0000265-06-002
# 22   0000265-06-003
# 23   0000265-06-004
# 24   0000265-06-005
# 25   0000265-06-006
# 26   0000265-06-007
# 27   0000265-06-008
# 28   0000265-07-001
# 29   0000265-08-001
# ..              ...
# 970  0015031-04-001
# 971  0015031-05-001
# 972  0015032-01-001
# 973  0015037-01-001
# 974  0015048-01-001
# 975  0015092-01-001
# 976  0015150-01-001
# 977  0015188-01-001
# 978  0015188-02-001
# 979  0015229-01-001
# 980  0015229-04-001
# 981  0015229-05-001
# 982  0015229-06-001
# 983  0015231-01-001
# 984  0015256-01-001
# 985  0015256-02-001
# 986  0015256-04-001
# 987  0015256-05-001
# 988  0015256-06-001
# 989  0015256-07-001
# 990  0015256-08-001
# 991  0015256-09-001
# 992  0015258-01-001
# 993  0015260-01-001
# 994  0015273-01-001
# 995  0015273-02-001
# 996  0015281-01-001
# 997  0015285-01-001
# 998  0015310-01-001
# 999  0015352-02-002
#
# [1000 rows x 26 columns]

# %%
table.count()
# Out:
# business_corridor                       2
# business_zip                         1000
# certificate_number                   1000
# city                                  999
# dba_end_date                          212
# dba_name                             1000
# dba_start_date                       1000
# full_business_address                1000
# lic                                   142
# lic_code_description                  124
# location                              974
# location_end_date                     340
# location_start_date                  1000
# mail_city                             788
# mail_state                            788
# mail_zipcode                          788
# mailing_address_1                     792
# naic_code                             702
# naic_code_description                 702
# neighborhoods_analysis_boundaries     800
# ownership_name                       1000
# parking_tax                          1000
# state                                 995
# supervisor_district                   800
# transient_occupancy_tax              1000
# ttxid                                1000
# dtype: int64

# %%
table = table[["dba_name", "dba_start_date", "dba_end_date", "business_zip", "naic_code_description"]]
table.head()
# Out:
#                     dba_name           dba_start_date dba_end_date  \
# 0           Eastman Kodak Co  2003-01-01T00:00:00.000          NaN
# 1           3101 Laguna Apts  1993-09-30T00:00:00.000          NaN
# 2           Ideal Novak Corp  1968-10-01T00:00:00.000          NaN
# 3              Tournahu Arms  1968-10-01T00:00:00.000          NaN
# 4  3301 Broderick Apartments  1968-10-01T00:00:00.000          NaN
#
#   business_zip                        naic_code_description
# 0        14650                                Manufacturing
# 1        94123  Real Estate and Rental and Leasing Services
# 2        94116  Real Estate and Rental and Leasing Services
# 3        94123                                          NaN
# 4        94123                                          NaN

# %%
table_rename = table.rename(columns={"dba_name": "Name",
                                      "dba_start_date": "Start Date",
                                      "dba_end_date": "End Date",
                                      "business_zip": "Zip code",
                                      "naic_code_description": "Sector"})
table_rename.head()
# Out:
#                         Name               Start Date End Date Zip code  \
# 0           Eastman Kodak Co  2003-01-01T00:00:00.000      NaN    14650
# 1           3101 Laguna Apts  1993-09-30T00:00:00.000      NaN    94123
# 2           Ideal Novak Corp  1968-10-01T00:00:00.000      NaN    94116
# 3              Tournahu Arms  1968-10-01T00:00:00.000      NaN    94123
# 4  3301 Broderick Apartments  1968-10-01T00:00:00.000      NaN    94123
#
#                                         Sector
# 0                                Manufacturing
# 1  Real Estate and Rental and Leasing Services
# 2  Real Estate and Rental and Leasing Services
# 3                                          NaN
# 4                                          NaN
