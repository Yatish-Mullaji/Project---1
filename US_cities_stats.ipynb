# %%
import pandas as pd

# Google developer API key
#from config import gkey

# Configure gmaps
#gmaps.configure(api_key=gkey)

# %%
#import data from csv files
file_jobs_2006=pd.read_csv("Idea1/business_2006.csv")
file_jobs_2006.head(100)
# Out:
#     FIPS   MSA CODE                              MSA DESCRIPTION   CODE  \
# 0             10020  Abbeville, LA Micropolitan Statistical Area     --
# 1             10020  Abbeville, LA Micropolitan Statistical Area     --
# 2             10020  Abbeville, LA Micropolitan Statistical Area     --
# 3             10020  Abbeville, LA Micropolitan Statistical Area     --
# 4             10020  Abbeville, LA Micropolitan Statistical Area     11
# 5             10020  Abbeville, LA Micropolitan Statistical Area     11
# 6             10020  Abbeville, LA Micropolitan Statistical Area     11
# 7             10020  Abbeville, LA Micropolitan Statistical Area     11
# 8             10020  Abbeville, LA Micropolitan Statistical Area     21
# 9             10020  Abbeville, LA Micropolitan Statistical Area     21
# 10            10020  Abbeville, LA Micropolitan Statistical Area     21
# 11            10020  Abbeville, LA Micropolitan Statistical Area     21
# 12            10020  Abbeville, LA Micropolitan Statistical Area     22
# 13            10020  Abbeville, LA Micropolitan Statistical Area     22
# 14            10020  Abbeville, LA Micropolitan Statistical Area     22
# 15            10020  Abbeville, LA Micropolitan Statistical Area     22
# 16            10020  Abbeville, LA Micropolitan Statistical Area     23
# 17            10020  Abbeville, LA Micropolitan Statistical Area     23
# 18            10020  Abbeville, LA Micropolitan Statistical Area     23
# 19            10020  Abbeville, LA Micropolitan Statistical Area     23
# 20            10020  Abbeville, LA Micropolitan Statistical Area  31-33
# 21            10020  Abbeville, LA Micropolitan Statistical Area  31-33
# 22            10020  Abbeville, LA Micropolitan Statistical Area  31-33
# 23            10020  Abbeville, LA Micropolitan Statistical Area  31-33
# 24            10020  Abbeville, LA Micropolitan Statistical Area     42
# 25            10020  Abbeville, LA Micropolitan Statistical Area     42
# 26            10020  Abbeville, LA Micropolitan Statistical Area     42
# 27            10020  Abbeville, LA Micropolitan Statistical Area     42
# 28            10020  Abbeville, LA Micropolitan Statistical Area  44-45
# 29            10020  Abbeville, LA Micropolitan Statistical Area  44-45
# ..              ...                                          ...    ...
# 70            10020  Abbeville, LA Micropolitan Statistical Area     71
# 71            10020  Abbeville, LA Micropolitan Statistical Area     71
# 72            10020  Abbeville, LA Micropolitan Statistical Area     72
# 73            10020  Abbeville, LA Micropolitan Statistical Area     72
# 74            10020  Abbeville, LA Micropolitan Statistical Area     72
# 75            10020  Abbeville, LA Micropolitan Statistical Area     72
# 76            10020  Abbeville, LA Micropolitan Statistical Area     81
# 77            10020  Abbeville, LA Micropolitan Statistical Area     81
# 78            10020  Abbeville, LA Micropolitan Statistical Area     81
# 79            10020  Abbeville, LA Micropolitan Statistical Area     81
# 80            10020  Abbeville, LA Micropolitan Statistical Area     99
# 81            10020  Abbeville, LA Micropolitan Statistical Area     99
# 82            10020  Abbeville, LA Micropolitan Statistical Area     99
# 83            10020  Abbeville, LA Micropolitan Statistical Area     99
# 84            10100   Aberdeen, SD Micropolitan Statistical Area     --
# 85            10100   Aberdeen, SD Micropolitan Statistical Area     --
# 86            10100   Aberdeen, SD Micropolitan Statistical Area     --
# 87            10100   Aberdeen, SD Micropolitan Statistical Area     --
# 88            10100   Aberdeen, SD Micropolitan Statistical Area     11
# 89            10100   Aberdeen, SD Micropolitan Statistical Area     11
# 90            10100   Aberdeen, SD Micropolitan Statistical Area     11
# 91            10100   Aberdeen, SD Micropolitan Statistical Area     11
# 92            10100   Aberdeen, SD Micropolitan Statistical Area     21
# 93            10100   Aberdeen, SD Micropolitan Statistical Area     21
# 94            10100   Aberdeen, SD Micropolitan Statistical Area     21
# 95            10100   Aberdeen, SD Micropolitan Statistical Area     21
# 96            10100   Aberdeen, SD Micropolitan Statistical Area     22
# 97            10100   Aberdeen, SD Micropolitan Statistical Area     22
# 98            10100   Aberdeen, SD Micropolitan Statistical Area     22
# 99            10100   Aberdeen, SD Micropolitan Statistical Area     22
#
#                                     NAICS DESCRIPTION  \
# 0                                               Total
# 1                                               Total
# 2                                               Total
# 3                                               Total
# 4   Forestry, Fishing, Hunting, and Agriculture Su...
# 5   Forestry, Fishing, Hunting, and Agriculture Su...
# 6   Forestry, Fishing, Hunting, and Agriculture Su...
# 7   Forestry, Fishing, Hunting, and Agriculture Su...
# 8                                              Mining
# 9                                              Mining
# 10                                             Mining
# 11                                             Mining
# 12                                          Utilities
# 13                                          Utilities
# 14                                          Utilities
# 15                                          Utilities
# 16                                       Construction
# 17                                       Construction
# 18                                       Construction
# 19                                       Construction
# 20                                      Manufacturing
# 21                                      Manufacturing
# 22                                      Manufacturing
# 23                                      Manufacturing
# 24                                    Wholesale Trade
# 25                                    Wholesale Trade
# 26                                    Wholesale Trade
# 27                                    Wholesale Trade
# 28                                       Retail Trade
# 29                                       Retail Trade
# ..                                                ...
# 70                Arts, Entertainment, and Recreation
# 71                Arts, Entertainment, and Recreation
# 72                    Accommodation and Food Services
# 73                    Accommodation and Food Services
# 74                    Accommodation and Food Services
# 75                    Accommodation and Food Services
# 76      Other Services (except Public Administration)
# 77      Other Services (except Public Administration)
# 78      Other Services (except Public Administration)
# 79      Other Services (except Public Administration)
# 80                                       Unclassified
# 81                                       Unclassified
# 82                                       Unclassified
# 83                                       Unclassified
# 84                                              Total
# 85                                              Total
# 86                                              Total
# 87                                              Total
# 88  Forestry, Fishing, Hunting, and Agriculture Su...
# 89  Forestry, Fishing, Hunting, and Agriculture Su...
# 90  Forestry, Fishing, Hunting, and Agriculture Su...
# 91  Forestry, Fishing, Hunting, and Agriculture Su...
# 92                                             Mining
# 93                                             Mining
# 94                                             Mining
# 95                                             Mining
# 96                                          Utilities
# 97                                          Utilities
# 98                                          Utilities
# 99                                          Utilities
#
#                   DATA TYPE    TOTAL     0-4     5-9   10-19   20-99 100-499  \
# 0                     Firms      932     491     155     103      81      26
# 1            Establishments      994     491     156     106      94      40
# 2                Employment    9,829     806     999   1,342   2,490   1,709
# 3   Annual Payroll ($1,000)  286,576  22,928  20,984  31,933  71,014  65,542
# 4                     Firms        9       7       2       0       0       0
# 5            Establishments        9       7       2       0       0       0
# 6                Employment       26     [a]     [a]       0       0       0
# 7   Annual Payroll ($1,000)      425     (D)     (D)       0       0       0
# 8                     Firms       22       9       1       3       3       0
# 9            Establishments       23       9       1       3       3       0
# 10               Employment      341     [a]     [a]      45     [b]       0
# 11  Annual Payroll ($1,000)   17,551     (D)     (D)   2,477     (D)       0
# 12                    Firms        5       1       1       0       0       1
# 13           Establishments        5       1       1       0       0       1
# 14               Employment       47     [a]     [a]       0       0     [b]
# 15  Annual Payroll ($1,000)    2,305     (D)     (D)       0       0     (D)
# 16                    Firms       83      53      17       9       1       3
# 17           Establishments       85      53      17       9       1       5
# 18               Employment    1,081      81     [c]     [c]     [b]     [f]
# 19  Annual Payroll ($1,000)   48,569   2,345     (D)     (D)     (D)     (D)
# 20                    Firms       42      12      11       6       8       2
# 21           Establishments       42      12      11       6       8       2
# 22               Employment      955     [a]     [b]     [b]     [e]     [b]
# 23  Annual Payroll ($1,000)   36,367     (D)     (D)     (D)     (D)     (D)
# 24                    Firms       45      16       5      10       7       2
# 25           Establishments       47      16       5      10       7       2
# 26               Employment      500      17     [b]     123     184     [a]
# 27  Annual Payroll ($1,000)   19,070     836     (D)   4,051   6,822     (D)
# 28                    Firms      177      82      25      24      17       6
# 29           Establishments      193      82      25      26      18       9
# ..                      ...      ...     ...     ...     ...     ...     ...
# 70               Employment       77     [b]       0     [a]     [b]       0
# 71  Annual Payroll ($1,000)      695     (D)       0     (D)     (D)       0
# 72                    Firms       61      20      11      12      10       2
# 73           Establishments       63      20      11      12      10       2
# 74               Employment      918      26      75     [c]     297     [b]
# 75  Annual Payroll ($1,000)    8,374     749     745     (D)   2,625     (D)
# 76                    Firms       81      51      19       8       2       0
# 77           Establishments       81      51      19       8       2       0
# 78               Employment      382     [c]     128     [b]     [b]       0
# 79  Annual Payroll ($1,000)    6,863     (D)   2,217     (D)     (D)       0
# 80                    Firms        5       5       0       0       0       0
# 81           Establishments        5       5       0       0       0       0
# 82               Employment        5       5       0       0       0       0
# 83  Annual Payroll ($1,000)       62      62       0       0       0       0
# 84                    Firms    1,384     703     246     145     122      57
# 85           Establishments    1,468     703     248     146     148      79
# 86               Employment   18,005   1,167   1,619   1,908   3,984   2,934
# 87  Annual Payroll ($1,000)  490,366  35,266  34,665  47,994  98,960  79,397
# 88                    Firms        7       6       1       0       0       0
# 89           Establishments        7       6       1       0       0       0
# 90               Employment      [a]     [a]     [a]       0       0       0
# 91  Annual Payroll ($1,000)      (D)     (D)     (D)       0       0       0
# 92                    Firms        2       1       0       0       1       0
# 93           Establishments        2       1       0       0       1       0
# 94               Employment      [b]     [a]       0       0     [b]       0
# 95  Annual Payroll ($1,000)      (D)     (D)       0       0     (D)       0
# 96                    Firms        7       0       0       1       2       1
# 97           Establishments        9       0       0       1       2       1
# 98               Employment      [c]       0       0     [a]     [b]     [a]
# 99  Annual Payroll ($1,000)      (D)       0       0     (D)     (D)     (D)
#
#        500+
# 0        76
# 1       107
# 2     2,483
# 3    74,175
# 4         0
# 5         0
# 6         0
# 7         0
# 8         6
# 9         7
# 10      190
# 11   10,580
# 12        2
# 13        2
# 14      [a]
# 15      (D)
# 16        0
# 17        0
# 18        0
# 19        0
# 20        3
# 21        3
# 22      [e]
# 23      (D)
# 24        5
# 25        7
# 26      [c]
# 27      (D)
# 28       23
# 29       33
# ..      ...
# 70      [a]
# 71      (D)
# 72        6
# 73        8
# 74      [e]
# 75      (D)
# 76        1
# 77        1
# 78      [a]
# 79      (D)
# 80        0
# 81        0
# 82        0
# 83        0
# 84      111
# 85      144
# 86    6,393
# 87  194,084
# 88        0
# 89        0
# 90        0
# 91        0
# 92        0
# 93        0
# 94        0
# 95        0
# 96        3
# 97        5
# 98      [b]
# 99      (D)
#
# [100 rows x 12 columns]

# %%
file_jobs_2006_clean=file_jobs_2006.rename(columns={'MSA DESCRIPTION': 'Metro Area',
                                                   'CODE': 'NAICS',
                                                   'NAICS DESCRIPTION': 'Industry',
                                                   'DATA TYPE': 'Filter',#total for years after 2013
                                                   'TOTAL': 'Total',
                                                   })
file_jobs_2006_clean.head()
# Out:
#    FIPS   MSA CODE                                   Metro Area NAICS  \
# 0            10020  Abbeville, LA Micropolitan Statistical Area    --
# 1            10020  Abbeville, LA Micropolitan Statistical Area    --
# 2            10020  Abbeville, LA Micropolitan Statistical Area    --
# 3            10020  Abbeville, LA Micropolitan Statistical Area    --
# 4            10020  Abbeville, LA Micropolitan Statistical Area    11
#
#                                             Industry                   Filter  \
# 0                                              Total                    Firms
# 1                                              Total           Establishments
# 2                                              Total               Employment
# 3                                              Total  Annual Payroll ($1,000)
# 4  Forestry, Fishing, Hunting, and Agriculture Su...                    Firms
#
#      Total     0-4     5-9   10-19   20-99 100-499    500+
# 0      932     491     155     103      81      26      76
# 1      994     491     156     106      94      40     107
# 2    9,829     806     999   1,342   2,490   1,709   2,483
# 3  286,576  22,928  20,984  31,933  71,014  65,542  74,175
# 4        9       7       2       0       0       0       0

# %%
jobs_2006=file_jobs_2006_clean[['Metro Area', 'NAICS', 'Industry', 'Filter', 'Total']]
jobs_2006.head()
# Out:
#                                     Metro Area NAICS  \
# 0  Abbeville, LA Micropolitan Statistical Area    --
# 1  Abbeville, LA Micropolitan Statistical Area    --
# 2  Abbeville, LA Micropolitan Statistical Area    --
# 3  Abbeville, LA Micropolitan Statistical Area    --
# 4  Abbeville, LA Micropolitan Statistical Area    11
#
#                                             Industry                   Filter  \
# 0                                              Total                    Firms
# 1                                              Total           Establishments
# 2                                              Total               Employment
# 3                                              Total  Annual Payroll ($1,000)
# 4  Forestry, Fishing, Hunting, and Agriculture Su...                    Firms
#
#      Total
# 0      932
# 1      994
# 2    9,829
# 3  286,576
# 4        9

# %%
jobs_2006['Industry'].unique()
# Out:
# array(['Total', 'Forestry, Fishing, Hunting, and Agriculture Support',
#        'Mining', 'Utilities', 'Construction', 'Manufacturing',
#        'Wholesale Trade', 'Retail Trade',
#        'Transportation and Warehousing', 'Information',
#        'Finance and Insurance', 'Real Estate and Rental and Leasing',
#        'Professional, Scientific, and Technical Services',
#        'Management of Companies and Enterprises',
#        'Administrative and Support and Waste Management and Remediation Services',
#        'Educational Services', 'Health Care and Social Assistance',
#        'Arts, Entertainment, and Recreation',
#        'Accommodation and Food Services',
#        'Other Services (except Public Administration)', 'Unclassified'],
#       dtype=object)

# %%
cities=['San Francisco-Oakland-Fremont, CA Metropolitan Statistical Area',
       #'Houston-Baytown-Sugar Land, TX Metropolitan Statistical Area',
       'Austin-Round Rock, TX Metropolitan Statistical Area',
       'Detroit-Warren-Livonia, MI Metropolitan Statistical Area',
       'Chicago-Naperville-Joliet, IL-IN-WI Metropolitan Statistical Area',
       'Boston-Cambridge-Quincy, MA-NH Metropolitan Statistical Area',
       'New York-Newark-Edison, NY-NJ-PA Metropolitan Statistical Area']

industries=['Mining', 
            'Manufacturing', 
            'Information', 
            'Finance and Insurance', 
            'Professional, Scientific, and Technical Services']
            
filters=['Establishments', 'Employment', 'Annual Payroll ($1,000)']

# %%
jobs_2006_cities=jobs_2006[jobs_2006['Metro Area'].isin(cities)]
jobs_2006_ind=jobs_2006_cities[jobs_2006_cities['Industry'].isin(industries)]
jobs_2006_filtered=jobs_2006_ind[jobs_2006_ind['Filter'].isin(filters)]
jobs_2006_filtered.to_csv('jobs_2006.csv')
jobs_2006_filtered.head()
# Out:
#                                              Metro Area  NAICS       Industry  \
# 4661  Austin-Round Rock, TX Metropolitan Statistical...     21         Mining
# 4662  Austin-Round Rock, TX Metropolitan Statistical...     21         Mining
# 4663  Austin-Round Rock, TX Metropolitan Statistical...     21         Mining
# 4673  Austin-Round Rock, TX Metropolitan Statistical...  31-33  Manufacturing
# 4674  Austin-Round Rock, TX Metropolitan Statistical...  31-33  Manufacturing
#
#                        Filter   Total
# 4661           Establishments     168
# 4662               Employment   1,439
# 4663  Annual Payroll ($1,000)  70,819
# 4673           Establishments   1,202
# 4674               Employment  50,637
